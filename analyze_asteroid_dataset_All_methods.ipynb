# %%
import numpy as np
import pandas as pd
import os
from checkRF_Score import *
from codes.utils.file import *
from codes.parameters import ASTRAL, WQFM, TRUE_ST, ASTEROID_RAxML_NG, ASTRID_RAxML_NG, ASTRALMP_RAxML_NG, ASTRID_FASTME_RAxML_NG, \
    BIPSTEP_RAxML_NG, FASTRFS_RAxML_NG_GREEDY, FASTRFS_RAxML_NG_SINGLE, METHOD_TO_ST

# %%
dataset_path = join_dir("dataset", "asteroid_dataset", "withils")
# dataset_path = join_dir("dataset","asteroid_simulated", "asteroid_data","simulations", "withoutils")

# %%
# in asteroid dataset
gt_file_name="true.true.geneTree.newick"
# gt_file_name = "raxml-ng.GTR+G.geneTree.newick"
species_tree_name="speciesTree.newick"
# species_tree_name= "fastrfs-raxml-ng_greedy.GTR+G.speciesTree.newick"

# %%
# for our experiment
gt_output_folder= "output"
gt_output_file_name= "1_gt.tre"
true_species_tree_name= "true-species.out.tree"
RF_SCORES_OUTPUT_DIR = "stats/RF_scores"
OUTPUT_ST_NAME = "method_st.newick"

# %%
def remove_and_create_output_folder(dir_current_path):
    remove_dir_current(dir_current_path)
    create_dir_current(dir_current_path)

# %%
import re

def remove_one(input_str):
    output_str = re.sub(r"1(?=[^\d_])", "", input_str)
    return output_str

def remove_numbers_after_colon(input_str):
    output_str = re.sub(r':[^,\)]+', '', input_str)
    output_str = remove_one(output_str)
    return output_str

def remove_numbers_before_and_after_colon(input_str):
    output_str = re.sub(r'((\d+\.\d+)|\d+):[^,\)]+', '', input_str)
    return output_str

def remove_numbers_after_colon_NO_NEED_TO_REMOVE_ONE(input_str):
    output_str = re.sub(r':[^,\)]+', '', input_str)
    return output_str

# like remove 0.42, 0.92 
def remove_numbers_after_decimal(input_str):
    output_str = re.sub(r'0\.\d+', '', input_str)
    return output_str

# %%
# provide families folder path
def get_all_GTs(families_folder):
    all_gts = []
    for dir in os.listdir(families_folder):
        # print(dir)
        # save mapping from mapping folder
        mapping={}
        mapping_dir="mappings"
        mapping_file_path=families_folder+"/"+dir+"/"+mapping_dir+"/treerecs_mapping.link"
        if os.path.exists(mapping_file_path):
            # print(mapping_file_path)
            with open(mapping_file_path) as f:
                for line in f:
                    # print(line)
                    (key, val) = line.split()
                    mapping[key] = val
        else:
            print("mapping file not found")
        if len(mapping) == 0:
            print("mapping is empty")
        # print(mapping)
        gt_tree_dir="gene_trees"
        gt_tree_file_path=families_folder+"/"+dir+"/"+gt_tree_dir+"/"+gt_file_name
        if not os.path.exists(gt_tree_file_path):
            print("file not exists")
            exit(1)
        with open(gt_tree_file_path) as f:
            line = f.readline()
            line = remove_numbers_after_colon(line)
            # print(line)
            for key in mapping:
                line = line.replace(key, mapping[key])
            all_gts.append(line)
            # print(line)
    #output to a file in output folder
    with open(gt_output_folder+"/"+gt_output_file_name, "w") as f:
        for gt in all_gts:
            f.write(gt+"\n")
            # f.write(gt)

# %%
def get_True_Species_Tree(source_folder):
    # copy species tree to output folder
    # species_tree_path = source_folder+"/species_trees/"+species_tree_name
    species_tree_path = join_dir(source_folder, "species_trees", species_tree_name)
    with open(species_tree_path) as f:
        line = f.readline()
        line = remove_numbers_after_colon_NO_NEED_TO_REMOVE_ONE(line)
        with open(gt_output_folder+"/"+true_species_tree_name, "w") as f:
            f.write(line)

# %%
def get_Species_Tree(source_folder, tree_name, method_name):
    species_tree_path = join_dir(source_folder, "species_trees", tree_name)
    with open(species_tree_path) as f:
        line = f.readline()
        if method_name == ASTRALMP_RAxML_NG:
            line = remove_numbers_before_and_after_colon(line)
        line = remove_numbers_after_colon_NO_NEED_TO_REMOVE_ONE(line)
        with open(gt_output_folder+"/"+OUTPUT_ST_NAME, "w") as f:
            f.write(line)
    f.close()

    copy_file_current(f"{gt_output_folder}/{OUTPUT_ST_NAME}", f"{gt_output_folder}/input.nwk")

# %%
def getTaxaSet(t):
    return t.replace('(', '').replace(')', '').split(';')[0].split(':')[0].split(',')

# %%
def get_INPUT_DATA():
    OUTGROUP = 'GAL'
    st = open('output/input.nwk')
    st = st.read()
    gts = open('output/1_gt.tre')

    gts = gts.read().split(';\n')[:-1] 

    # print(len(gts))

    # print(st)
    taxaSet = getTaxaSet(st)
    # print(taxaSet)
    matrix = np.zeros((len(taxaSet), len(gts)), dtype=int)


    # print(len(gts))
    for gt_idx, gt in  enumerate(gts) :
        # print(gt)
        cur_taxaSet = getTaxaSet(gt)
        # print(cur_taxaSet)
        for i, tx in enumerate(taxaSet):
            if tx  in cur_taxaSet or tx == OUTGROUP:
                matrix[i][gt_idx] = 1
    with open('output/input.data', 'w', newline='') as f:
        print(matrix.shape[0], matrix.shape[1], file=f)
        for i in range(len(taxaSet)):
            # f.write(matrix[i].tostring(), taxaSet[i])
            print(*matrix[i],taxaSet[i], end='\n', file=f)

# %%
def getTerrace():
    # !rm -rf terrace_output
    remove_dir_current("terrace_output")
    # !mkdir -p terrace_output
    create_dir_current("terrace_output")
    
    # !./bin/raxml-ng output/input.nwk output/input.data > terrace_output/terrace_output.txt

# %%
def getConsensusTree():
    # get consensus tree
    terrace_dir = join_dir(TERRACE_OUTPUT_FOLDER)
    consensus_dir = join_dir(terrace_dir, "consensus")
    # !rm -rf "$consensus_dir"
    # !mkdir "$consensus_dir"

    if not dir_exists_abs(terrace_dir):
        print("Directory does not exist: {}".format(terrace_dir))
        exit(1)
    for terrace_file in os.listdir(terrace_dir):
        file_path = join_dir(terrace_dir, terrace_file)
        if file_path.endswith(".txt"):
            # print("Processing file: {}".format(file_path))
            terrace_file_name = terrace_file.split(".")[0]
            # !./bin/raxml-ng --consense MRE --tree "$file_path" --prefix "$consensus_dir"/"$terrace_file_name"

# %%
def get_ASTRAL_tree():
    # !rm -rf in/
    remove_dir_current("in")
    # !rm -rf out/
    remove_dir_current("out")
    # !mkdir in
    create_dir_current("in")
    # !cp output/1_gt.tre in/
    copy_file_current("output/1_gt.tre", "in/1_gt.tre")
    
    # !python3 postprocessor.py
    # !cp out/complete/astral/1_gt_species.out.tre output/input.nwk
    copy_file_current("out/complete/astral/1_gt_species.out.tre", f"{gt_output_folder}/input.nwk")

# %%
def get_True_ST_as_speciesTree():
    copy_file_current(f"{gt_output_folder}/{true_species_tree_name}", f"{gt_output_folder}/input.nwk")

# %%
# def get_asteroid_raxml_as_ST():
    # copy_file_current

# %%
def get_wQFM_tree():
    # !rm -rf in/
    remove_dir_current("in")
    # !rm -rf out/
    remove_dir_current("out")
    # !mkdir in
    create_dir_current("in")
    # !cp output/1_gt.tre in/
    copy_file_current("output/1_gt.tre", "in/1_gt.tre")
    
    # !python3 postprocessor.py
    # !cp out/complete/astral/1_gt_species.out.tre output/input.nwk
    copy_file_current("out/complete/wQFM/1_gt_species.tre", "output/input.nwk")

# %%
def get_ASTRAL_RF_Score(true_tree):
    astral_rf_score = calculate_RF_distance_for_a_ST(join_dir(gt_output_folder, "input.nwk"), true_tree)
    print("astral_rf_score --> ", astral_rf_score)
    return astral_rf_score

# %%
def get_Terrace_RF_Scores(true_tree):
    
    #get RF score for each tree in Terrace
    terrace_rf_scores=calculate_RF_distance_for_terrace(join_dir(TERRACE_OUTPUT_FOLDER, "terrace_output.txt"), true_tree)
    # print("terrace_rf_scores", terrace_rf_scores)
    if terrace_rf_scores is not None:
        return terrace_rf_scores
    else:
        return []

# %%
def get_Consensus_RF_score(true_tree):
    terrace_dir = join_dir(TERRACE_OUTPUT_FOLDER)
    consensus_dir = join_dir(terrace_dir, "consensus")
    CONSENSUS_TREE_EXTENSION = "consensusTreeMRE"
    file_path = join_dir(consensus_dir, "terrace_output.raxml.consensusTreeMRE")
    # print("Processing file: {}".format(file_path))
    # print("True Tree --> ", true_tree)
    # remove_numbers_from_consensus_tree(file_path)
    if file_exists_absolute(file_path):
        dist = calculate_RF_distance_for_a_ST(file_path, true_tree)
        print("Consensus RF distance: {}".format(dist))
        return dist
    else:
        print("File does not exist: {}".format(file_path))
        return -1

# %%
def Keep_few_STs_in_Terrace(KEEPING_STs_NUM):
    num_of_trees_in_terrace = 0
    for file in os.listdir("terrace_output"):
        if file.endswith(".txt"):
            file_path = "terrace_output/"+file
            
            if os.path.getsize(file_path) <= 0:
                return -1 # no trees in terrace
            
            df = pd.read_csv(file_path)
            num_of_trees_in_terrace = len(df)
            if len(df) > KEEPING_STs_NUM:
                df = df.iloc[:KEEPING_STs_NUM]
                df.to_csv(file_path, index=False)
    return num_of_trees_in_terrace

# %%
def get_stats_of_terrace(terrace_rf_scores,true_tree, astral_rf):
    return calculate_RF_AND_generate_stats_OF_TERRACE_Return_better_trees(terrace_rf_scores,true_tree, astral_rf)

# %%
import datetime
def get_time():
    now = datetime.datetime.now()
    return now.strftime("%d_%b_%Y_%H_%M%p")

# %%
METHODS_FROM_ASTEROID_DATASET = [ASTEROID_RAxML_NG, ASTRID_RAxML_NG, ASTRALMP_RAxML_NG, ASTRID_FASTME_RAxML_NG, BIPSTEP_RAxML_NG, FASTRFS_RAxML_NG_GREEDY, FASTRFS_RAxML_NG_SINGLE]

def run_analysis(numberOfSpecies, USED_METHOD=ASTRAL):   
    csv_out = []
    csv_out.append(["Model Condition", "RF Score", "Consensus RF" , "Better Trees Consensus RF Score", "Trees Better than "+USED_METHOD, "Trees Equal to "+USED_METHOD, "Tress worse than "+USED_METHOD])
    i=0
    MODEL_CONDITION = numberOfSpecies

    #remove and create dir of rf scores
    MODEL_CONDITION_DIR = f"{RF_SCORES_OUTPUT_DIR}/{MODEL_CONDITION}"
    remove_and_create_output_folder(MODEL_CONDITION_DIR)

    for model_condition in sorted(os.listdir(dataset_path)):
        # if i==3:
            # i+=1
            # continue
        # print(model_condition)
        if MODEL_CONDITION not in model_condition:
            continue
        # if "ms0.8_mf0.0" not in model_condition:
            # continue
        
        print("Model Condition --> ", model_condition)

        remove_and_create_output_folder(gt_output_folder) 

        source_folder = join_dir(dataset_path, model_condition)
        # print(source_folder)
        # source_folder="dataset/asteroid_dataset/withils/ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3000"
        families_folder = join_dir(source_folder, "families")
        get_all_GTs(families_folder)
        get_True_Species_Tree(source_folder)
        
        true_tree = join_dir(gt_output_folder, true_species_tree_name)
        
        if USED_METHOD == ASTRAL:
            get_ASTRAL_tree()
        elif USED_METHOD == WQFM:
            get_wQFM_tree()
        elif USED_METHOD == TRUE_ST:
            get_True_ST_as_speciesTree()
        elif USED_METHOD in METHODS_FROM_ASTEROID_DATASET:
            get_Species_Tree(source_folder, METHOD_TO_ST[USED_METHOD], USED_METHOD)
        else:
            print("Invalid method")
            return 

        get_INPUT_DATA()

        print("GET TERRACE")
        getTerrace()
        print("GET TERRACE DONE")

        MAX_STs_IN_TERRACE = 20000 
        number_of_trees_in_terrace = Keep_few_STs_in_Terrace(MAX_STs_IN_TERRACE)
        print("number_of_trees_in_terrace --> ", number_of_trees_in_terrace)
        if number_of_trees_in_terrace == -1:
            i+=1
            print("\n\n=============No trees in terrace================\n\n")
            continue
        #get rf scores of each tree in terrace
        terrace_file_path = join_dir(TERRACE_OUTPUT_FOLDER, "terrace_output.txt")
        # terrace_rf_scores = calculate_RF_distance_for_terrace(terrace_file_path, true_tree)
        
        # rf scores
        astral_rf = get_ASTRAL_RF_Score(true_tree)
        if number_of_trees_in_terrace >1:
            #consensus of trees of terrace
            getConsensusTree()
            
            consensus_rf = get_Consensus_RF_score(true_tree)

            # get stats of how many trees are better/eq/worse than ASTRAL
            print("get rf scores of terrace trees")
            better, equal, worse, better_trees, rf_scores_csv_terrace = get_stats_of_terrace(terrace_file_path,true_tree, astral_rf)
            print("rf_scores_csv_terrace done ")
            # save rf scores of terrace trees
            rf_scores_csv_terrace_file_path = f'{MODEL_CONDITION_DIR}/{model_condition}_rf_scores_terrace.csv'
            with open(rf_scores_csv_terrace_file_path, 'w') as f:
                csv.writer(f).writerows(rf_scores_csv_terrace)

            print(f"Better: {better}, Equal: {equal}, Worse: {worse}")
            
            rf_score_better_trees_consensus = None

            if better>1:
                # print("Better trees --> ", better_trees)

                better_trees_file_path = f'{gt_output_folder}/better_trees.txt'
                with open(better_trees_file_path, 'w') as f:
                    f.writelines(better_trees)
                f.close()

                # !./bin/raxml-ng --consense MRE --tree "$better_trees_file_path" --prefix "$gt_output_folder"/"better_trees"
                better_trees_consensus_file_path = f'{gt_output_folder}/better_trees.raxml.consensusTreeMRE'

                rf_score_better_trees_consensus = calculate_RF_distance_for_a_ST(better_trees_consensus_file_path, true_tree)
                # print("RF score of better trees consensus --> ", rf_score_better_trees_consensus)
                
            # csv_out.append([model_condition, astral_rf, consensus_rf])
            csv_out.append([model_condition, astral_rf, consensus_rf, rf_score_better_trees_consensus, better, equal, worse]) 
        
        i+=1
        if i>=8:
            break
    
    stat_fl = f'stats/Summary_{MODEL_CONDITION}_{get_time()}_{USED_METHOD}.csv'
    with open(stat_fl, 'w') as stat_file:
        csv.writer(stat_file).writerows(csv_out)

    # stat_fl = 'stats/Summary_terrace.csv'
    # with open(stat_fl, 'w') as stat_file:
    #     csv.writer(stat_file).writerows(csv_out_terrace)

# %%
create_dir_current(RF_SCORES_OUTPUT_DIR)
# MODEL_CONDITIONS = ["s25", "s50", "s75", "s100"]
MODEL_CONDITIONS = [ "s25" ]
for model_condition in MODEL_CONDITIONS:
    print(f"\n\nstarting analysis for {model_condition} at {get_time()}\n\n")
    run_analysis(model_condition, USED_METHOD=ASTRAL)
    print(f"\n\nfinished analysis for {model_condition} at {get_time()}\n\n")
# Out:
# starting analysis for s25 at 06_May_2023_22_07PM
#
#
# Model Condition -->  ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3000
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 478 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at 24
#
# ======== Running the main analysis
# Number of taxa: 25 (25 species)
# Taxa: [24, 20, 9, 18, 6, 12, 3, 15, 4, 14, 22, 11, 17, 8, 21, 1, 7, 5, 13, 10, 2, 19, 23, 25, 16]
# Taxon occupancy: {22=168, 23=29, 24=133, 25=102, 10=37, 11=85, 12=47, 13=47, 14=242, 15=169, 16=45, 17=197, 18=42, 19=65, 1=95, 2=37, 3=153, 4=172, 5=75, 6=191, 7=136, 8=108, 9=165, 20=187, 21=87}
# Number of gene trees: 478
# 478 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 233
# Number of Clusters after addition by distance: 233
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:675
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 233
# gradient0 in heuristiic: 233
# partitions formed in 0.169 secs
# Dynamic Programming starting after 0.169 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 17821
# Polytree building time: 0.007 seconds.
# Number of quartet trees in the gene trees: 17821
# Size of largest cluster: 25
# Greedy score: 15718
# estimationFactor: 1.1337956483013105
# Sub-optimal score: 17223
# Total Number of elements weighted: 236
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.966444082823635
# Optimization score: 17223
# Optimal tree inferred in 0.221 secs.
# (6,(2,(18,((12,16),((9,((21,(24,19)),(22,(20,(23,25))))),(((4,17),(11,(14,5))),(1,((15,7),(10,(8,(3,13)))))))))));
# Final quartet score is: 17223
# Final normalized quartet score is: 0.966444082823635
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{23, 25}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 14:
# 	{20, 23, 25}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{14, 5}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{3, 13}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{3, 8, 13}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 12:
# 	{3, 8, 13, 10}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{12, 16}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{6, 2}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{18, 6, 2}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 19:
# 	{20, 9, 18, 6, 12, 3, 15, 4, 14, 22, 11, 17, 8, 1, 7, 5, 13, 10, 2, 23, 25, 16}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{20, 9, 18, 6, 12, 3, 15, 4, 14, 22, 11, 17, 8, 21, 1, 7, 5, 13, 10, 2, 23, 25, 16}
# (24,(19,(21,((22,(20,(23,25)0.95:0.9808292530117262)1:2.302585092994046)1:3.283414346005771,(9,((((4,17)1:1.5960148921019601,(11,(14,5)1:1.5404450409471486)1:1.0826119473216684)1:4.6379600088110795,(1,((15,7)1:2.730029107820986,(10,(8,(3,13)0.58:0.15415067982725836)0.87:0.6931471805599453)0.99:0.7731898882334817)1:3.091042453358317)1:1.3710268889891024)1:1.2205021062771466,((12,16)0.67:0.2876820724517809,(18,(2,6)0.67:0.2876820724517809)0.99:1.3862943611198908)1:3.3787245258100977)1:4.116323468940871)1:3.4657359027997248)1:2.590267165445826)0.95:0.9808292530117262));
# Weight calculation took 0.026210173 secs
# ASTRAL finished in 0.322 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# GET TERRACE
# GET TERRACE DONE
# number_of_trees_in_terrace -->  8
# astral_rf_score -->  0.045454545454545456
#
# RAxML-NG v. 1.1.0-master released on 04.08.2022 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M1, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 06-May-2023 22:07:07 as follows:
#
# ./bin/raxml-ng --consense MRE --tree terrace_output/terrace_output.txt --prefix terrace_output/consensus/terrace_output
#
# Analysis options:
#   run mode: Build consensus tree (MRE)
#   start tree(s): user
#   random seed: 1683389227
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# Reading input trees from file: terrace_output/terrace_output.txt
# Loaded 9 trees with 25 taxa.
#
# MRE consensus tree saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.consensusTreeMRE
#
# Execution log saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.log
#
# Analysis started: 06-May-2023 22:07:07 / finished: 06-May-2023 22:07:07
#
# Elapsed time: 0.003 seconds
#
# Consensus RF distance: 0.045454545454545456
# get rf scores of terrace trees
# rf_scores_csv_terrace done
# Better: 1.0, Equal: 4.0, Worse: 4.0
# Model Condition -->  ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3001
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 497 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at 15
#
# ======== Running the main analysis
# Number of taxa: 25 (25 species)
# Taxa: [15, 5, 2, 1, 9, 7, 23, 20, 24, 22, 17, 6, 11, 12, 14, 16, 10, 18, 19, 13, 25, 4, 21, 3, 8]
# Taxon occupancy: {22=41, 23=162, 24=85, 25=179, 10=177, 11=144, 12=70, 13=111, 14=102, 15=145, 16=127, 17=93, 18=160, 19=243, 1=177, 2=51, 3=73, 4=43, 5=171, 6=156, 7=94, 8=93, 9=86, 20=70, 21=78}
# Number of gene trees: 497
# 497 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 271
# Number of Clusters after addition by distance: 271
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:675
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 271
# gradient0 in heuristiic: 271
# partitions formed in 0.168 secs
# Dynamic Programming starting after 0.168 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 18746
# Polytree building time: 0.014 seconds.
# Number of quartet trees in the gene trees: 18746
# Size of largest cluster: 25
# Greedy score: 18379
# estimationFactor: 1.0199684422438653
# Sub-optimal score: 18379
# Total Number of elements weighted: 266
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.980422490131228
# Optimization score: 18379
# Optimal tree inferred in 0.228 secs.
# (9,(6,((4,(15,(11,(5,3)))),((2,12),((1,13),((14,(16,(7,(10,8)))),((24,22),((17,25),(23,((20,18),(19,21)))))))))));
# Final quartet score is: 18379
# Final normalized quartet score is: 0.980422490131228
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{5, 3}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 19:
# 	{5, 11, 3}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{2, 12}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{10, 8}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 12:
# 	{7, 10, 8}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 17:
# 	{7, 16, 10, 8}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 7:
# 	{24, 22}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 14:
# 	{20, 18}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 15:
# 	{19, 21}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 11:
# 	{2, 1, 9, 7, 23, 20, 24, 22, 17, 6, 12, 14, 16, 10, 18, 19, 13, 25, 21, 8}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 10:
# 	{2, 1, 9, 7, 23, 20, 24, 22, 17, 6, 12, 14, 16, 10, 18, 19, 13, 25, 4, 21, 8}
# (15,((11,(5,3)0.99:1.3862943611198908)1:0.7576857016975165,(4,(((2,12)1:1.5404450409471486,((1,13)1:3.3557350075853964,((14,(16,(7,(10,8)0.72:0.2876820724517809)0.89:0.3677247801253174)1:2.484906649788)1:3.5835189384561117,((24,22)1:1.6739764335716716,((17,25)1:2.730029107820986,(23,((20,18)0.75:0.2231435513142097,(19,21)1:2.367123614131617)1:3.3557350075853964)1:3.6198865826269824)1:3.5835189384561117)1:3.8985999850960074)1:4.492374691842744)0.06:0.0)1:2.302585092994046,(6,9)1:2.6855773452501523)1:1.3862943611198908)0.61:0.14660347419187525));
# Weight calculation took 0.028313212 secs
# ASTRAL finished in 0.28 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# GET TERRACE
# GET TERRACE DONE
# number_of_trees_in_terrace -->  0
# astral_rf_score -->  0.09090909090909091
# Model Condition -->  ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3002
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 466 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at 21
#
# ======== Running the main analysis
# Number of taxa: 25 (25 species)
# Taxa: [21, 14, 10, 4, 3, 17, 25, 24, 23, 5, 16, 1, 6, 11, 15, 20, 8, 13, 7, 2, 19, 22, 18, 12, 9]
# Taxon occupancy: {22=101, 23=159, 24=82, 25=153, 10=158, 11=54, 12=56, 13=114, 14=124, 15=84, 16=119, 17=147, 18=50, 19=98, 1=105, 2=32, 3=163, 4=203, 5=145, 6=65, 7=47, 8=107, 9=28, 20=70, 21=226}
# Number of gene trees: 466
# 466 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 181
# Number of Clusters after addition by distance: 181
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:675
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 181
# gradient0 in heuristiic: 181
# partitions formed in 0.148 secs
# Dynamic Programming starting after 0.148 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 17392
# Polytree building time: 0.007 seconds.
# Number of quartet trees in the gene trees: 17392
# Size of largest cluster: 25
# Greedy score: 16976
# estimationFactor: 1.0245051837888783
# Sub-optimal score: 16983
# Total Number of elements weighted: 207
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.9764834406623735
# Optimization score: 16983
# Optimal tree inferred in 0.197 secs.
# (19,((18,(17,9)),(13,((22,12),((25,20),((21,(24,15)),(((16,11),(23,(14,10))),((4,2),((5,(3,1)),(8,(6,7)))))))))));
# Final quartet score is: 16983
# Final normalized quartet score is: 0.9764834406623735
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 8:
# 	{24, 15}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 7:
# 	{16, 11}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 13:
# 	{14, 10}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 9:
# 	{4, 2}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 14:
# 	{3, 1}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{6, 7}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 14:
# 	{6, 8, 7}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 7:
# 	{22, 12}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{17, 9}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{17, 18, 9}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 9:
# 	{17, 19, 18, 9}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 16:
# 	{17, 13, 19, 18, 9}
# (21,((24,15)1:1.7917594692280545,((((16,11)1:1.6739764335716716,(23,(14,10)1:2.2335922215070947)1:1.7540191412452077)1:4.01337549968843,((4,2)0.99:0.9162907318741553,((5,(3,1)1:2.302585092994046)1:2.890371757896163,(8,(6,7)0.87:0.6931471805599453)1:2.302585092994046)0.97:0.25259075264051095)1:4.422848629194136)1:3.710858360832714,((25,20)1:2.6390573296152575,((22,12)0.74:0.2876820724517809,(13,((18,(17,9)0.33:0.0)0.67:0.2876820724517809,19)0.84:0.3686511349854482)0.98:0.5559460590464603)1:2.3978952727983716)1:3.9765615265657206)1:3.688879454113933));
# Weight calculation took 0.023677958 secs
# ASTRAL finished in 0.247 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# GET TERRACE
# GET TERRACE DONE
# number_of_trees_in_terrace -->  4
# astral_rf_score -->  0.09090909090909091
#
# RAxML-NG v. 1.1.0-master released on 04.08.2022 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M1, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 06-May-2023 22:07:11 as follows:
#
# ./bin/raxml-ng --consense MRE --tree terrace_output/terrace_output.txt --prefix terrace_output/consensus/terrace_output
#
# Analysis options:
#   run mode: Build consensus tree (MRE)
#   start tree(s): user
#   random seed: 1683389231
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# Reading input trees from file: terrace_output/terrace_output.txt
# Loaded 5 trees with 25 taxa.
#
# MRE consensus tree saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.consensusTreeMRE
#
# Execution log saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.log
#
# Analysis started: 06-May-2023 22:07:11 / finished: 06-May-2023 22:07:11
#
# Elapsed time: 0.002 seconds
#
# Consensus RF distance: 0.09090909090909091
# get rf scores of terrace trees
# rf_scores_csv_terrace done
# Better: 1.0, Equal: 4.0, Worse: 0.0
# Model Condition -->  ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3003
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 535 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at 2
#
# ======== Running the main analysis
# Number of taxa: 25 (25 species)
# Taxa: [2, 3, 13, 8, 23, 11, 21, 15, 16, 25, 5, 22, 24, 9, 4, 10, 20, 6, 1, 17, 7, 19, 12, 18, 14]
# Taxon occupancy: {22=76, 23=163, 24=101, 25=175, 10=63, 11=190, 12=63, 13=264, 14=128, 15=91, 16=35, 17=46, 18=64, 19=126, 1=94, 2=119, 3=199, 4=97, 5=159, 6=84, 7=92, 8=248, 9=200, 20=161, 21=224}
# Number of gene trees: 535
# 535 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 307
# Number of Clusters after addition by distance: 307
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:675
# polytomy size limit : 3
# discarded polytomies:  [3]
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 307
# max k is :0
# Number of Clusters after addition by greedy: 307
# gradient0 in heuristiic: 307
# partitions formed in 0.225 secs
# Dynamic Programming starting after 0.225 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 26194
# Polytree building time: 0.008 seconds.
# Number of quartet trees in the gene trees: 26194
# Size of largest cluster: 25
# Greedy score: 24449
# estimationFactor: 1.0713730622929363
# Sub-optimal score: 24449
# Total Number of elements weighted: 477
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.9355577613193862
# Optimization score: 24506
# Optimal tree inferred in 0.3 secs.
# (7,(10,(14,(16,(5,((3,9),(1,((2,18),((6,(13,12)),(((8,17),(11,(15,4))),((25,24),((21,22),(19,(23,20))))))))))))));
# Final quartet score is: 24506
# Final normalized quartet score is: 0.9355577613193862
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{13, 12}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 10:
# 	{8, 17}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 7:
# 	{15, 4}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 18:
# 	{21, 22}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{23, 20}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{10, 7}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{10, 7, 14}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{16, 10, 7, 14}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 12:
# 	{3, 13, 8, 23, 11, 21, 15, 16, 25, 5, 22, 24, 9, 4, 10, 20, 6, 1, 17, 7, 19, 12, 14}
# (2,(18,(((6,(13,12)0.98:1.2039728043259361)1:3.4657359027997248,(((8,17)1:1.9924301646902058,(11,(15,4)0.74:0.2876820724517809)1:3.149882953381249)0.22:0.0,((25,24)1:2.2335922215070947,((21,22)1:1.8458266904983307,(19,(23,20)0.97:0.8472978603872037)1:0.8823891801984738)1:3.8712010109078943)1:4.521788577049036)1:2.0990500130682137)1:3.270835563798911,(1,((3,9)1:2.730029107820986,(5,(16,(14,(10,7)0.93:0.6931471805599453)0.95:0.9808292530117262)0.53:0.1053605156578264)1:0.6443570163905135)1:0.9028677115420143)0.9:0.2876820724517809)1:1.466337068793427));
# Weight calculation took 0.050121082 secs
# ASTRAL finished in 0.354 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# GET TERRACE
# GET TERRACE DONE
# number_of_trees_in_terrace -->  0
# astral_rf_score -->  0.13636363636363635
# Model Condition -->  ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3004
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 417 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at 8
#
# ======== Running the main analysis
# Number of taxa: 25 (25 species)
# Taxa: [8, 13, 11, 19, 1, 16, 9, 24, 10, 3, 2, 18, 20, 23, 25, 5, 21, 4, 7, 17, 14, 15, 12, 6, 22]
# Taxon occupancy: {22=44, 23=44, 24=98, 25=108, 10=74, 11=172, 12=108, 13=78, 14=102, 15=73, 16=160, 17=168, 18=164, 19=33, 1=116, 2=54, 3=102, 4=99, 5=147, 6=29, 7=65, 8=19, 9=124, 20=162, 21=27}
# Number of gene trees: 417
# 417 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 221
# Number of Clusters after addition by distance: 221
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:675
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 221
# gradient0 in heuristiic: 221
# partitions formed in 0.133 secs
# Dynamic Programming starting after 0.133 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 12622
# Polytree building time: 0.007 seconds.
# Number of quartet trees in the gene trees: 12622
# Size of largest cluster: 25
# Greedy score: 12445
# estimationFactor: 1.0142225793491362
# Sub-optimal score: 12446
# Total Number of elements weighted: 210
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.9860560925368405
# Optimization score: 12446
# Optimal tree inferred in 0.178 secs.
# (14,(20,(9,((18,6),((23,(24,25)),(((10,21),((1,12),(3,(16,(5,4))))),((8,(7,17)),(22,((19,15),(2,(13,11)))))))))));
# Final quartet score is: 12446
# Final normalized quartet score is: 0.9860560925368405
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{7, 17}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{19, 15}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{13, 11}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 10:
# 	{13, 11, 2}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{13, 11, 19, 2, 15}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 10:
# 	{13, 11, 19, 2, 15, 22}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{10, 21}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 19:
# 	{1, 12}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 13:
# 	{5, 4}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{24, 25}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 16:
# 	{24, 23, 25}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{18, 6}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 12:
# 	{20, 14}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{13, 11, 19, 1, 16, 9, 24, 10, 3, 2, 18, 20, 23, 25, 5, 21, 4, 14, 15, 12, 6, 22}
# (8,((7,17)0.33:0.0,((22,((19,15)0.67:0.2876820724517809,(2,(13,11)0.83:0.4418327522790392)0.62:0.20067069546215124)0.87:0.6931471805599453)1:1.9924301646902058,(((10,21)1:1.5404450409471486,((1,12)1:2.590267165445826,(3,(16,(5,4)0.99:0.6241543090729941)1:2.6390573296152575)1:2.2335922215070947)1:1.4816045409242156)1:3.768922161787476,((23,(24,25)0.98:1.2039728043259361)1:2.4277482359480516,((18,6)0.99:1.3862943611198908,(9,(20,14)1:2.159484249353373)1:0.6931471805599453)1:3.5457786104732607)1:4.469732215092986)1:4.382026634673885)0.99:1.3862943611198908));
# Weight calculation took 0.022549379 secs
# ASTRAL finished in 0.225 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# GET TERRACE
# GET TERRACE DONE
# number_of_trees_in_terrace -->  14
# astral_rf_score -->  0.0
#
# RAxML-NG v. 1.1.0-master released on 04.08.2022 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M1, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 06-May-2023 22:07:14 as follows:
#
# ./bin/raxml-ng --consense MRE --tree terrace_output/terrace_output.txt --prefix terrace_output/consensus/terrace_output
#
# Analysis options:
#   run mode: Build consensus tree (MRE)
#   start tree(s): user
#   random seed: 1683389234
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# Reading input trees from file: terrace_output/terrace_output.txt
# Loaded 15 trees with 25 taxa.
#
# MRE consensus tree saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.consensusTreeMRE
#
# Execution log saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.log
#
# Analysis started: 06-May-2023 22:07:14 / finished: 06-May-2023 22:07:14
#
# Elapsed time: 0.002 seconds
#
# Consensus RF distance: 0.09090909090909091
# get rf scores of terrace trees
# rf_scores_csv_terrace done
# Better: 0.0, Equal: 1.0, Worse: 14.0
# Model Condition -->  ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3005
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 525 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at 10
#
# ======== Running the main analysis
# Number of taxa: 25 (25 species)
# Taxa: [10, 11, 20, 19, 14, 6, 16, 12, 17, 4, 24, 3, 18, 8, 23, 22, 13, 9, 1, 5, 7, 2, 21, 15, 25]
# Taxon occupancy: {22=133, 23=117, 24=150, 25=46, 10=126, 11=74, 12=126, 13=31, 14=162, 15=65, 16=194, 17=133, 18=116, 19=185, 1=138, 2=32, 3=84, 4=201, 5=58, 6=199, 7=126, 8=138, 9=117, 20=203, 21=134}
# Number of gene trees: 525
# 525 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 235
# Number of Clusters after addition by distance: 235
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:675
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 235
# gradient0 in heuristiic: 235
# partitions formed in 0.204 secs
# Dynamic Programming starting after 0.204 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 19547
# Polytree building time: 0.008 seconds.
# Number of quartet trees in the gene trees: 19547
# Size of largest cluster: 25
# Greedy score: 17858
# estimationFactor: 1.0945794601859111
# Sub-optimal score: 18055
# Total Number of elements weighted: 252
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.9448508722566122
# Optimization score: 18469
# Optimal tree inferred in 0.259 secs.
# (14,((6,(3,5)),(18,(((9,(4,7)),((17,8),(2,(16,12)))),(19,((13,15),((10,(11,(20,1))),(25,((24,22),(23,21))))))))));
# Final quartet score is: 18469
# Final normalized quartet score is: 0.9448508722566122
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 7:
# 	{20, 1}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{11, 20, 1}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 12:
# 	{24, 22}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 14:
# 	{23, 21}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 8:
# 	{24, 23, 22, 21}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{13, 15}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 8:
# 	{4, 7}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{16, 12}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{16, 12, 2}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{3, 5}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 18:
# 	{6, 3, 5}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 13:
# 	{14, 6, 3, 5}
# (10,((11,(20,1)0.99:0.9808292530117262)1:1.5404450409471486,((25,((24,22)0.97:0.5500463369192721,(23,21)0.89:0.35667494393873245)1:1.7917594692280545)1:2.730029107820986,((13,15)0.51:0.13353139262452263,(19,(((9,(4,7)1:1.0986122886681098)1:1.0033021088637848,((17,8)1:0.6281147102890909,(2,(16,12)0.67:0.2876820724517809)0.99:1.3862943611198908)0.99:0.2784654173468569)1:3.3081069585961425,(18,((6,(3,5)0.84:0.5108256237659905)0.99:0.5930637220029626,14)1:1.5404450409471486)1:3.721669276936928)1:0.8529958815018415)0.77:0.1758906664636643)1:3.283414346005771)1:2.772588722239782));
# Weight calculation took 0.029564716 secs
# ASTRAL finished in 0.311 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# GET TERRACE
# GET TERRACE DONE
# number_of_trees_in_terrace -->  8
# astral_rf_score -->  0.0
#
# RAxML-NG v. 1.1.0-master released on 04.08.2022 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M1, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 06-May-2023 22:07:16 as follows:
#
# ./bin/raxml-ng --consense MRE --tree terrace_output/terrace_output.txt --prefix terrace_output/consensus/terrace_output
#
# Analysis options:
#   run mode: Build consensus tree (MRE)
#   start tree(s): user
#   random seed: 1683389236
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# Reading input trees from file: terrace_output/terrace_output.txt
# Loaded 9 trees with 25 taxa.
#
# MRE consensus tree saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.consensusTreeMRE
#
# Execution log saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.log
#
# Analysis started: 06-May-2023 22:07:16 / finished: 06-May-2023 22:07:16
#
# Elapsed time: 0.002 seconds
#
# Consensus RF distance: 0.09090909090909091
# get rf scores of terrace trees
# rf_scores_csv_terrace done
# Better: 0.0, Equal: 1.0, Worse: 8.0
# Model Condition -->  ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3006
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 595 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at 13
#
# ======== Running the main analysis
# Number of taxa: 25 (25 species)
# Taxa: [13, 7, 16, 19, 4, 12, 10, 14, 23, 22, 15, 24, 17, 6, 25, 1, 5, 8, 21, 3, 11, 20, 18, 9, 2]
# Taxon occupancy: {22=260, 23=98, 24=258, 25=129, 10=213, 11=150, 12=176, 13=133, 14=181, 15=329, 16=223, 17=119, 18=67, 19=164, 1=169, 2=27, 3=58, 4=183, 5=227, 6=228, 7=86, 8=145, 9=45, 20=55, 21=181}
# Number of gene trees: 595
# 595 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 269
# Number of Clusters after addition by distance: 269
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:675
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 269
# gradient0 in heuristiic: 269
# partitions formed in 0.184 secs
# Dynamic Programming starting after 0.184 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 39566
# Polytree building time: 0.01 seconds.
# Number of quartet trees in the gene trees: 39566
# Size of largest cluster: 25
# Greedy score: 37380
# estimationFactor: 1.0584804708400215
# Sub-optimal score: 37444
# Total Number of elements weighted: 321
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.9463680938179245
# Optimization score: 37444
# Optimal tree inferred in 0.252 secs.
# (4,(3,((1,2),(((11,(9,(14,25))),((12,10),((21,18),(19,22)))),((17,(23,5)),(6,((13,(15,8)),((7,20),(16,24)))))))));
# Final quartet score is: 37444
# Final normalized quartet score is: 0.9463680938179245
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{7, 20}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 18:
# 	{16, 24}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{23, 5}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{14, 25}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{14, 25, 9}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 19:
# 	{21, 18}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{1, 2}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 8:
# 	{4, 3}
# (13,((15,8)0.8:0.24116205681688796,(((7,20)0.42:0.0,(16,24)1:2.538973871058275)1:0.9245484171131366,(6,((17,(23,5)0.53:0.1053605156578264)1:3.688879454113933,(((11,(9,(14,25)0.42:0.0)0.95:0.9808292530117262)0.09:0.0,((12,10)0.91:0.23468954231127054,((21,18)1:2.590267165445826,(19,22)1:2.0794415416798353)1:0.4541302800894454)1:4.6821312271242155)1:4.830976854721778,((1,2)0.99:1.3862943611198908,(3,4)1:1.7917594692280545)1:3.828641396489098)1:4.7535901911063565)1:3.688879454113933)1:0.5778735565089874)1:1.2630617206959425));
# Weight calculation took 0.042649666 secs
# ASTRAL finished in 0.308 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# GET TERRACE
# GET TERRACE DONE
# number_of_trees_in_terrace -->  0
# astral_rf_score -->  0.09090909090909091
# Model Condition -->  ssim_veryhighmiss_s25_f1000_sites100_GTR_bl1.0_d0.0_l0.0_t0.0_gc0.0_p0.0_pop50000000_ms0.6_mf0.6_seed3007
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 385 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at 12
#
# ======== Running the main analysis
# Number of taxa: 25 (25 species)
# Taxa: [12, 5, 19, 21, 11, 7, 4, 1, 25, 23, 16, 9, 20, 2, 22, 8, 15, 10, 14, 6, 3, 24, 18, 17, 13]
# Taxon occupancy: {22=115, 23=67, 24=10, 25=152, 10=48, 11=81, 12=98, 13=17, 14=66, 15=71, 16=67, 17=20, 18=77, 19=96, 1=165, 2=101, 3=22, 4=87, 5=133, 6=79, 7=114, 8=108, 9=18, 20=74, 21=158}
# Number of gene trees: 385
# 385 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 221
# Number of Clusters after addition by distance: 221
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:675
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 221
# gradient0 in heuristiic: 221
# partitions formed in 0.167 secs
# Dynamic Programming starting after 0.167 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 7494
# Polytree building time: 0.005 seconds.
# Number of quartet trees in the gene trees: 7494
# Size of largest cluster: 25
# Greedy score: 7464
# estimationFactor: 1.0040192926045015
# Sub-optimal score: 7464
# Total Number of elements weighted: 201
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.9959967974379503
# Optimization score: 7464
# Optimal tree inferred in 0.208 secs.
# (3,(4,(((22,(24,(25,23))),(1,(6,(10,13)))),((8,((7,16),(21,11))),((9,(12,(15,(5,17)))),((2,18),(20,(19,14))))))));
# Final quartet score is: 7464
# Final normalized quartet score is: 0.9959967974379503
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{5, 17}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{5, 15, 17}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 7:
# 	{2, 18}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{19, 14}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{19, 20, 14}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 7:
# 	{7, 16}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 8:
# 	{21, 11}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 18:
# 	{21, 11, 7, 16}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{25, 23}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{25, 23, 24}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{10, 13}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{10, 6, 13}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{4, 3}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{19, 21, 11, 7, 4, 1, 25, 23, 16, 20, 2, 22, 8, 10, 14, 6, 3, 24, 18, 13}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{19, 21, 11, 7, 4, 1, 25, 23, 16, 9, 20, 2, 22, 8, 10, 14, 6, 3, 24, 18, 13}
# (12,((15,(5,17)0.67:0.2876820724517809)0.85:0.4418327522790392,(9,(((2,18)1:1.6739764335716716,(20,(19,14)0.99:1.3862943611198908)1:1.5404450409471486)1:3.444682493601893,((8,((7,16)0.74:0.2876820724517809,(21,11)1:1.7917594692280545)1:2.538973871058275)1:2.2192034840549946,(((22,(24,(25,23)0.87:0.6931471805599453)0.87:0.6931471805599453)1:3.2580965380214812,(1,(6,(10,13)0.33:0.0)0.99:1.3862943611198908)1:2.961830721878311)1:3.3081069585961425,(4,3)0.95:0.9808292530117262)1:3.912023005428148)1:3.705408756065146)0.98:1.2039728043259361)0.33:0.0));
# Weight calculation took 0.019797962 secs
# ASTRAL finished in 0.263 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# GET TERRACE
# GET TERRACE DONE
# number_of_trees_in_terrace -->  314
# astral_rf_score -->  0.13636363636363635
#
# RAxML-NG v. 1.1.0-master released on 04.08.2022 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M1, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 06-May-2023 22:07:20 as follows:
#
# ./bin/raxml-ng --consense MRE --tree terrace_output/terrace_output.txt --prefix terrace_output/consensus/terrace_output
#
# Analysis options:
#   run mode: Build consensus tree (MRE)
#   start tree(s): user
#   random seed: 1683389240
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# Reading input trees from file: terrace_output/terrace_output.txt
# Loaded 315 trees with 25 taxa.
#
# MRE consensus tree saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.consensusTreeMRE
#
# Execution log saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/terrace_output/consensus/terrace_output.raxml.log
#
# Analysis started: 06-May-2023 22:07:20 / finished: 06-May-2023 22:07:20
#
# Elapsed time: 0.023 seconds
#
# Consensus RF distance: 0.13636363636363635
# get rf scores of terrace trees
# rf_scores_csv_terrace done
# Better: 53.0, Equal: 94.0, Worse: 168.0
#
# RAxML-NG v. 1.1.0-master released on 04.08.2022 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: Apple M1, 8 cores, 8 GB RAM
#
# RAxML-NG was called at 06-May-2023 22:07:36 as follows:
#
# ./bin/raxml-ng --consense MRE --tree output/better_trees.txt --prefix output/better_trees
#
# Analysis options:
#   run mode: Build consensus tree (MRE)
#   start tree(s): user
#   random seed: 1683389256
#   SIMD kernels: SSE3
#   parallelization: coarse-grained (auto), PTHREADS (auto)
#
# Reading input trees from file: output/better_trees.txt
# Loaded 53 trees with 25 taxa.
#
# MRE consensus tree saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/output/better_trees.raxml.consensusTreeMRE
#
# Execution log saved to: /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/output/better_trees.raxml.log
#
# Analysis started: 06-May-2023 22:07:36 / finished: 06-May-2023 22:07:36
#
# Elapsed time: 0.003 seconds
#
#
#
# finished analysis for s25 at 06_May_2023_22_07PM
