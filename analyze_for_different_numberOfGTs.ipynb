# %%
import numpy as np
import pandas as pd

# %%
GT_FILE_NAME = '1_gt.tre'
TEST_NUMBER_OF_GTS = 5

# %%
# !mkdir -p in
# !cp dataset/taxa-37/gene-tree/noscale.200g.500b/1_gt.tre in/

# %%
#keep first 10 lines of the file. Delete the rest
file = open("in/"+GT_FILE_NAME, "r")
file_content = file.readlines()
file.close()
file = open("in/"+GT_FILE_NAME, "w")
file_content = file_content[:TEST_NUMBER_OF_GTS]
file.writelines(file_content)
file.close()

# %%
# !./run_for_different_range.sh
# Out:
# Running Preprocessing......................
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/gt/1_gt.tre
# --------------- Pruning started  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/gt/1_gt.tre (  8 - 15 ) ---------------
# --------------- Pruning done  0 s  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/gt/1_gt.tre (  8 - 15 ) ---------------
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/gt/1_gt.tre
# --------------- Pruning started  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/gt/1_gt.tre (  12 - 14 ) ---------------
# --------------- Pruning done  0 s  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/gt/1_gt.tre (  12 - 14 ) ---------------
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/gt/1_gt.tre
# --------------- Pruning started  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/gt/1_gt.tre (  13 - 16 ) ---------------
# --------------- Pruning done  0 s  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/gt/1_gt.tre (  13 - 16 ) ---------------
#
#
# ------------------- preprocessor ran in  0.052667856216430664 s -------------
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 5 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at ORN
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [ORN, ECH, LOX, PRO, SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH, DAS, CHO, SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI, GAL, MON, MAC]
# Taxon occupancy: {PTE=5, NEW=5, RAT=5, TAR=5, SPE=5, ORN=5, OTO=5, CHO=5, PRO=5, ORY=5, MYO=5, MIC=5, HOM=5, BOS=5, EQU=5, DIP=5, MUS=5, ECH=5, GOR=5, FEL=5, MON=5, TUP=5, PON=5, MAC=5, CAL=5, TUR=5, SUS=5, VIC=5, CAN=5, GAL=5, LOX=5, OCH=5, DAS=5, SOR=5, CAV=5, PAN=5, ERI=5}
# Number of gene trees: 5
# 0 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 241
# Number of Clusters after addition by distance: 241
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 4
# discarded polytomies:  [3, 4]
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# polytomy of size 4; rounds with additions with at least 5 support: 0; clusters: 247
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 249
# max k is :0
# Number of Clusters after addition by greedy: 249
# gradient0 in heuristiic: 249
# partitions formed in 0.069 secs
# Dynamic Programming starting after 0.069 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 330225
# Polytree building time: 0.002 seconds.
# Number of quartet trees in the gene trees: 330225
# Size of largest cluster: 37
# Greedy score: 283677
# estimationFactor: 1.1640880296957454
# Sub-optimal score: 283989
# Total Number of elements weighted: 258
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.8653948065712772
# Optimization score: 285775
# Optimal tree inferred in 0.099 secs.
# (OCH,(ORY,((SPE,(DIP,(CAV,(RAT,MUS)))),((TAR,((MIC,OTO),(CAL,(NEW,(PON,(GOR,(PAN,HOM))))))),(TUP,(((DAS,CHO),((ECH,(LOX,PRO)),(ORN,(GAL,(MON,MAC))))),((SOR,ERI),((PTE,MYO),((EQU,(FEL,CAN)),(VIC,(SUS,(BOS,TUR))))))))))));
# Final quartet score is: 285775
# Final normalized quartet score is: 0.8653948065712772
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{GAL, MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{LOX, PRO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{ECH, LOX, PRO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{DAS, CHO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SOR, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{PTE, MYO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{EQU, FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{BOS, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{BOS, TUR, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{VIC, BOS, TUR, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{VIC, BOS, TUR, SUS, EQU, FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{MIC, OTO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{GOR, PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{GOR, PAN, HOM, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{GOR, PAN, HOM, NEW, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{CAL, GOR, PAN, HOM, NEW, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{MIC, OTO, CAL, GOR, PAN, HOM, NEW, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{MIC, OTO, TAR, CAL, GOR, PAN, HOM, NEW, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{RAT, MUS, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{DIP, RAT, MUS, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, DIP, RAT, MUS, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, DIP, RAT, MUS, CAV, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, DIP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH, SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH, DAS, CHO, SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{ECH, LOX, PRO, SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH, DAS, CHO, SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI}
# (ORN,((GAL,(MON,MAC)0.93:0.6785483811387927)0.72:0.2876820724517809,((ECH,(LOX,PRO)0.93:0.6931471805599453)0.99:1.3862943611198908,((DAS,CHO)0.99:1.3862943611198908,(((SOR,ERI)0.67:0.2513144282809059,((PTE,MYO)0.99:1.3862943611198908,((EQU,(FEL,CAN)0.93:0.6931471805599453)0.94:0.7099542988763263,(VIC,(SUS,(BOS,TUR)0.93:0.6931471805599453)0.83:0.4700036292457356)0.99:1.3862943611198908)0.69:0.27584761480477815)0.68:0.2876820724517809)0.99:1.1856236656577395,(TUP,((TAR,((MIC,OTO)0.99:1.3862943611198908,(CAL,(NEW,(PON,(GOR,(PAN,HOM)0.72:0.2876820724517809)0.99:1.3862943611198908)0.67:0.2876820724517809)0.4:0.0)0.74:0.35667494393873245)0.4:0.0)0.98:1.0759127011520033,((SPE,(DIP,(CAV,(RAT,MUS)0.99:1.3862943611198908)0.67:0.2876820724517809)0.57:0.1823215567939546)0.96:0.826678573184468,(ORY,OCH)0.93:0.6931471805599453)0.59:0.22413610722696134)0.49:0.06984357336726445)0.86:0.4953214372300254)0.82:0.428845556752228)0.67:0.2876820724517809)0.99:1.3862943611198908));
# Weight calculation took 0.006135927 secs
# ASTRAL finished in 0.151 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 5 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/gt/1_gt.tre
# All output trees will be *arbitrarily* rooted at ORN
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [ORN, LOX, SPE, TUP, MIC, RAT, MUS, CAL, PAN, PON, ORY, OCH, CHO, SOR, BOS, TUR, PTE, EQU, FEL, ERI, GAL, MON, MAC, DAS, MYO, DIP, TAR, NEW, HOM, GOR, VIC, SUS, PRO, CAN, ECH, OTO, CAV]
# Taxon occupancy: {PTE=2, NEW=3, RAT=5, TAR=3, SPE=3, ORN=3, CHO=3, OTO=2, PRO=3, ORY=4, MYO=3, MIC=5, BOS=5, HOM=2, EQU=3, MUS=5, DIP=2, GOR=4, ECH=2, FEL=3, MON=4, TUP=4, PON=3, MAC=3, CAL=4, TUR=4, SUS=3, VIC=2, CAN=2, GAL=4, LOX=5, OCH=3, SOR=3, DAS=3, CAV=1, PAN=3, ERI=5}
# Number of gene trees: 5
# 5 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 247
# Number of Clusters after addition by distance: 247
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 3
# discarded polytomies:  [3]
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 247
# max k is :0
# Number of Clusters after addition by greedy: 247
# gradient0 in heuristiic: 247
# partitions formed in 0.097 secs
# Dynamic Programming starting after 0.097 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 59886
# Polytree building time: 0.002 seconds.
# Number of quartet trees in the gene trees: 59886
# Size of largest cluster: 37
# Greedy score: 51573
# estimationFactor: 1.1611889942411726
# Sub-optimal score: 51573
# Total Number of elements weighted: 227
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.868700531008917
# Optimization score: 52023
# Optimal tree inferred in 0.127 secs.
# (MIC,(OTO,(((SPE,DIP),(CAV,(RAT,MUS))),((ORY,OCH),((TAR,((CAL,NEW),(PON,(GOR,(PAN,HOM))))),(TUP,(((CHO,DAS),((PRO,(LOX,ECH)),(ORN,(GAL,(MON,MAC))))),(ERI,(MYO,((EQU,(FEL,CAN)),(PTE,(SOR,((BOS,TUR),(VIC,SUS))))))))))))));
# Final quartet score is: 52023
# Final normalized quartet score is: 0.868700531008917
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{GAL, MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{LOX, ECH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{LOX, PRO, ECH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{CHO, DAS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{EQU, FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{BOS, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{VIC, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{BOS, TUR, VIC, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{SOR, BOS, TUR, VIC, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{SOR, BOS, TUR, PTE, VIC, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{SOR, BOS, TUR, PTE, EQU, FEL, VIC, SUS, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{SOR, BOS, TUR, PTE, EQU, FEL, MYO, VIC, SUS, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SOR, BOS, TUR, PTE, EQU, FEL, ERI, MYO, VIC, SUS, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{CAL, NEW}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{PAN, HOM, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{PAN, PON, HOM, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{CAL, PAN, PON, NEW, HOM, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{CAL, PAN, PON, TAR, NEW, HOM, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{SPE, DIP}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{RAT, MUS, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, RAT, MUS, DIP, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{MIC, OTO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, MIC, RAT, MUS, DIP, OTO, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, MIC, RAT, MUS, ORY, OCH, DIP, OTO, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, MIC, RAT, MUS, CAL, PAN, PON, ORY, OCH, DIP, TAR, NEW, HOM, GOR, OTO, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, TUP, MIC, RAT, MUS, CAL, PAN, PON, ORY, OCH, DIP, TAR, NEW, HOM, GOR, OTO, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, TUP, MIC, RAT, MUS, CAL, PAN, PON, ORY, OCH, SOR, BOS, TUR, PTE, EQU, FEL, ERI, MYO, DIP, TAR, NEW, HOM, GOR, VIC, SUS, CAN, OTO, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, TUP, MIC, RAT, MUS, CAL, PAN, PON, ORY, OCH, CHO, SOR, BOS, TUR, PTE, EQU, FEL, ERI, DAS, MYO, DIP, TAR, NEW, HOM, GOR, VIC, SUS, CAN, OTO, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{LOX, SPE, TUP, MIC, RAT, MUS, CAL, PAN, PON, ORY, OCH, CHO, SOR, BOS, TUR, PTE, EQU, FEL, ERI, DAS, MYO, DIP, TAR, NEW, HOM, GOR, VIC, SUS, PRO, CAN, ECH, OTO, CAV}
# (ORN,((GAL,(MON,MAC)0.65:0.2652092165997223)0.67:0.2876820724517809,((PRO,(LOX,ECH)0.67:0.2876820724517809)0.95:0.9808292530117262,((CHO,DAS)0.87:0.6931471805599453,((ERI,(MYO,((EQU,(FEL,CAN)0.67:0.2876820724517809)0.42:0.0,(PTE,(SOR,((BOS,TUR)0.87:0.6931471805599453,(VIC,SUS)0.42:0.0)0.67:0.2876820724517809)0.67:0.2876820724517809)0.67:0.2876820724517809)0.74:0.4054651081081643)0.55:0.16989903679539747)0.99:1.2039728043259357,(TUP,((TAR,((CAL,NEW)0.87:0.6931471805599453,(PON,(GOR,(PAN,HOM)0.67:0.2876820724517809)0.87:0.6931471805599453)0.95:0.9808292530117262)0.93:0.8288924328444882)0.86:0.6076250071217831,((ORY,OCH)0.77:0.42121346507630353,(((SPE,DIP)0.67:0.2876820724517809,(CAV,(RAT,MUS)0.67:0.2876820724517809)0.67:0.2876820724517809)0.86:0.5374938708481518,(OTO,MIC)0.87:0.6931471805599453)0.36:0.029852963149681045)0.61:0.23617451530584893)0.7:0.2876820724517809)0.84:0.5108256237659905)0.61:0.1823215567939546)0.44:0.1053605156578264)0.95:0.9808292530117262));
# Weight calculation took 0.009653836 secs
# ASTRAL finished in 0.15 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.out.tre
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 5 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/gt/1_gt.tre
# All output trees will be *arbitrarily* rooted at ECH
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [ECH, LOX, PRO, SPE, TUP, OTO, MUS, CAL, PAN, HOM, PON, ORY, DAS, CHO, SOR, BOS, TUR, PTE, MYO, FEL, CAN, GAL, MAC, CAV, DIP, OCH, NEW, GOR, VIC, SUS, EQU, MON, ORN, ERI, TAR, MIC, RAT]
# Taxon occupancy: {PTE=4, NEW=3, TAR=2, RAT=1, SPE=5, ORN=4, OTO=5, CHO=4, PRO=4, ORY=4, MYO=4, MIC=1, HOM=2, BOS=5, EQU=2, MUS=3, DIP=4, ECH=4, GOR=4, FEL=4, MON=2, TUP=3, PON=3, MAC=4, CAL=5, TUR=2, SUS=2, CAN=3, VIC=2, GAL=5, LOX=4, OCH=3, DAS=3, SOR=4, CAV=3, PAN=3, ERI=1}
# Number of gene trees: 5
# 5 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 245
# Number of Clusters after addition by distance: 245
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 3
# discarded polytomies:  [3, 3]
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 247
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 249
# max k is :0
# Number of Clusters after addition by greedy: 249
# gradient0 in heuristiic: 249
# partitions formed in 0.066 secs
# Dynamic Programming starting after 0.066 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 55660
# Polytree building time: 0.002 seconds.
# Number of quartet trees in the gene trees: 55660
# Size of largest cluster: 37
# Greedy score: 47622
# estimationFactor: 1.1687875351728192
# Sub-optimal score: 48586
# Total Number of elements weighted: 237
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.8831117499101688
# Optimization score: 49154
# Optimal tree inferred in 0.091 secs.
# (RAT,(CAV,(MUS,(DIP,(SPE,((ORY,OCH),(((TAR,(OTO,MIC)),(NEW,(CAL,(PON,(PAN,(HOM,GOR)))))),(TUP,(((DAS,CHO),((ECH,(LOX,PRO)),(ORN,(GAL,(MAC,MON))))),((SOR,ERI),((PTE,MYO),((CAN,(FEL,EQU)),(VIC,(SUS,(BOS,TUR)))))))))))))));
# Final quartet score is: 49154
# Final normalized quartet score is: 0.8831117499101688
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{LOX, PRO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{MAC, MON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{GAL, MAC, MON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{GAL, MAC, MON, ORN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{DAS, CHO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{SOR, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{PTE, MYO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{FEL, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{FEL, CAN, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{BOS, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{BOS, TUR, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{BOS, TUR, VIC, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{BOS, TUR, FEL, CAN, VIC, SUS, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{BOS, TUR, PTE, MYO, FEL, CAN, VIC, SUS, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SOR, BOS, TUR, PTE, MYO, FEL, CAN, VIC, SUS, EQU, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{OTO, MIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{OTO, TAR, MIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{HOM, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{PAN, HOM, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{PAN, HOM, PON, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{CAL, PAN, HOM, PON, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{CAL, PAN, HOM, PON, NEW, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{OTO, CAL, PAN, HOM, PON, NEW, GOR, TAR, MIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{CAV, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{MUS, CAV, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{MUS, CAV, DIP, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, MUS, CAV, DIP, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, MUS, ORY, CAV, DIP, OCH, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{SPE, OTO, MUS, CAL, PAN, HOM, PON, ORY, CAV, DIP, OCH, NEW, GOR, TAR, MIC, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{SPE, TUP, OTO, MUS, CAL, PAN, HOM, PON, ORY, CAV, DIP, OCH, NEW, GOR, TAR, MIC, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, TUP, OTO, MUS, CAL, PAN, HOM, PON, ORY, SOR, BOS, TUR, PTE, MYO, FEL, CAN, CAV, DIP, OCH, NEW, GOR, VIC, SUS, EQU, ERI, TAR, MIC, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, TUP, OTO, MUS, CAL, PAN, HOM, PON, ORY, DAS, CHO, SOR, BOS, TUR, PTE, MYO, FEL, CAN, CAV, DIP, OCH, NEW, GOR, VIC, SUS, EQU, ERI, TAR, MIC, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, TUP, OTO, MUS, CAL, PAN, HOM, PON, ORY, DAS, CHO, SOR, BOS, TUR, PTE, MYO, FEL, CAN, GAL, MAC, CAV, DIP, OCH, NEW, GOR, VIC, SUS, EQU, MON, ORN, ERI, TAR, MIC, RAT}
# (ECH,((LOX,PRO)0.95:0.9808292530117262,((ORN,(GAL,(MAC,MON)0.87:0.6931471805599453)0.67:0.2876820724517809)0.98:1.2039728043259361,((DAS,CHO)0.95:0.9808292530117262,(((SOR,ERI)0.67:0.2876820724517809,((PTE,MYO)0.95:0.9808292530117262,((CAN,(FEL,EQU)0.33:0.0)0.87:0.6931471805599453,(VIC,(SUS,(BOS,TUR)0.33:0.0)0.87:0.6931471805599453)0.87:0.6931471805599453)0.67:0.2876820724517809)0.78:0.39304258810960735)0.98:1.2039728043259361,(TUP,(((TAR,(OTO,MIC)0.33:0.0)0.42:0.0,(NEW,(CAL,(PON,(PAN,(HOM,GOR)0.67:0.2876820724517809)0.87:0.6931471805599453)0.95:0.9808292530117262)0.33:0.0)0.68:0.2876820724517809)0.87:0.5201280164283044,((ORY,OCH)0.87:0.6931471805599453,(SPE,(DIP,(MUS,(CAV,RAT)0.33:0.0)0.67:0.2876820724517809)0.84:0.5108256237659905)0.88:0.5533852381847867)0.51:0.17435338714477766)0.69:0.29605032212229754)0.71:0.33420208808667373)0.79:0.4307829160924542)0.84:0.5108256237659905)0.98:1.2039728043259361));
# Weight calculation took 0.005617212 secs
# ASTRAL finished in 0.116 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.out.tre
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 5 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/gt/1_gt.tre
# All output trees will be *arbitrarily* rooted at ORN
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [ORN, ECH, PRO, SPE, TUP, RAT, MUS, CAV, GOR, PAN, HOM, ORY, DAS, CHO, VIC, TUR, SUS, PTE, MYO, CAN, GAL, DIP, OCH, NEW, CAL, MIC, OTO, PON, BOS, FEL, MON, EQU, TAR, MAC, ERI, LOX, SOR]
# Taxon occupancy: {PTE=3, NEW=2, RAT=5, TAR=2, SPE=4, ORN=4, CHO=3, OTO=4, PRO=4, ORY=2, MYO=2, MIC=3, HOM=4, BOS=3, EQU=2, MUS=5, DIP=4, ECH=1, GOR=4, FEL=2, MON=3, TUP=1, PON=2, MAC=3, CAL=3, TUR=5, SUS=2, VIC=3, CAN=2, GAL=4, LOX=2, OCH=2, DAS=5, SOR=1, CAV=5, PAN=4, ERI=1}
# Number of gene trees: 5
# 5 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 269
# Number of Clusters after addition by distance: 269
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 4
# discarded polytomies:  [4]
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# polytomy of size 4; rounds with additions with at least 5 support: 0; clusters: 271
# max k is :0
# Number of Clusters after addition by greedy: 271
# gradient0 in heuristiic: 271
# partitions formed in 0.07 secs
# Dynamic Programming starting after 0.07 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 38766
# Polytree building time: 0.003 seconds.
# Number of quartet trees in the gene trees: 38766
# Size of largest cluster: 37
# Greedy score: 34257
# estimationFactor: 1.1316227340397582
# Sub-optimal score: 34955
# Total Number of elements weighted: 286
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.9078574008151473
# Optimization score: 35194
# Optimal tree inferred in 0.096 secs.
# (TUP,((GOR,(PAN,HOM)),(PON,((TAR,(MIC,OTO)),((NEW,CAL),(((SPE,OCH),(CAV,(DIP,(RAT,MUS)))),(((DAS,CHO),(ORY,((ECH,(PRO,LOX)),(GAL,(MAC,(ORN,MON)))))),(ERI,((PTE,MYO),(CAN,((SOR,(FEL,EQU)),(VIC,(SUS,(TUR,BOS))))))))))))));
# Final quartet score is: 35194
# Final normalized quartet score is: 0.9078574008151473
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{PRO, LOX}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{ECH, PRO, LOX}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{DAS, CHO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{PTE, MYO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{FEL, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{FEL, EQU, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{TUR, BOS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{TUR, SUS, BOS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{VIC, TUR, SUS, BOS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{VIC, TUR, SUS, BOS, FEL, EQU, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{VIC, TUR, SUS, CAN, BOS, FEL, EQU, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{VIC, TUR, SUS, PTE, MYO, CAN, BOS, FEL, EQU, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{VIC, TUR, SUS, PTE, MYO, CAN, BOS, FEL, EQU, ERI, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{SPE, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{RAT, MUS, DIP}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{RAT, MUS, CAV, DIP}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, RAT, MUS, CAV, DIP, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{NEW, CAL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{MIC, OTO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{MIC, OTO, TAR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{GOR, PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{TUP, GOR, PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{TUP, GOR, PAN, HOM, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{TUP, GOR, PAN, HOM, MIC, OTO, PON, TAR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{TUP, GOR, PAN, HOM, NEW, CAL, MIC, OTO, PON, TAR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, TUP, RAT, MUS, CAV, GOR, PAN, HOM, DIP, OCH, NEW, CAL, MIC, OTO, PON, TAR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, TUP, RAT, MUS, CAV, GOR, PAN, HOM, VIC, TUR, SUS, PTE, MYO, CAN, DIP, OCH, NEW, CAL, MIC, OTO, PON, BOS, FEL, EQU, TAR, ERI, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{SPE, TUP, RAT, MUS, CAV, GOR, PAN, HOM, DAS, CHO, VIC, TUR, SUS, PTE, MYO, CAN, DIP, OCH, NEW, CAL, MIC, OTO, PON, BOS, FEL, EQU, TAR, ERI, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{SPE, TUP, RAT, MUS, CAV, GOR, PAN, HOM, ORY, DAS, CHO, VIC, TUR, SUS, PTE, MYO, CAN, DIP, OCH, NEW, CAL, MIC, OTO, PON, BOS, FEL, EQU, TAR, ERI, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{ECH, PRO, SPE, TUP, RAT, MUS, CAV, GOR, PAN, HOM, ORY, DAS, CHO, VIC, TUR, SUS, PTE, MYO, CAN, DIP, OCH, NEW, CAL, MIC, OTO, PON, BOS, FEL, EQU, TAR, ERI, LOX, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{ECH, PRO, SPE, TUP, RAT, MUS, CAV, GOR, PAN, HOM, ORY, DAS, CHO, VIC, TUR, SUS, PTE, MYO, CAN, GAL, DIP, OCH, NEW, CAL, MIC, OTO, PON, BOS, FEL, EQU, TAR, ERI, LOX, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{ECH, PRO, SPE, TUP, RAT, MUS, CAV, GOR, PAN, HOM, ORY, DAS, CHO, VIC, TUR, SUS, PTE, MYO, CAN, GAL, DIP, OCH, NEW, CAL, MIC, OTO, PON, BOS, FEL, EQU, TAR, MAC, ERI, LOX, SOR}
# (ORN,(MON,(MAC,(GAL,((ECH,(PRO,LOX)0.33:0.0)0.67:0.2876820724517809,(ORY,((DAS,CHO)0.95:0.9808292530117262,((ERI,((PTE,MYO)0.87:0.6931471805599453,(CAN,((SOR,(FEL,EQU)0.33:0.0)0.67:0.2876820724517809,(VIC,(SUS,(TUR,BOS)0.67:0.2876820724517809)0.67:0.2876820724517809)0.67:0.2876820724517809)0.33:0.0)0.42:0.0)0.67:0.2876820724517809)0.67:0.2876820724517809,(((SPE,OCH)0.67:0.2876820724517809,(CAV,(DIP,(RAT,MUS)0.98:1.2039728043259361)0.44:0.1053605156578264)0.93:0.6931471805599453)0.91:0.6131044728864091,((NEW,CAL)0.67:0.2876820724517809,((TAR,(MIC,OTO)0.67:0.2876820724517809)0.45:0.031748698314580416,(PON,((GOR,(PAN,HOM)0.67:0.2876820724517809)0.67:0.2876820724517809,TUP)0.33:0.0)0.87:0.6931471805599453)0.44:0.1053605156578264)0.97:1.0216512475319814)0.95:0.7801585575495753)0.85:0.4700036292457356)0.63:0.24116205681688824)0.87:0.6931471805599453)0.98:1.2039728043259361)0.67:0.2876820724517809)0.42:0.0));
# Weight calculation took 0.006243287 secs
# ASTRAL finished in 0.12 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.out.tre
# Finding Terraces for different ranges......
# [NbConvertApp] Converting notebook processor.ipynb to script
# [NbConvertApp] Writing 1330 bytes to processor.py
# [NbConvertApp] Converting notebook processor.ipynb to script
# [NbConvertApp] Writing 1330 bytes to processor.py
# [NbConvertApp] Converting notebook processor.ipynb to script
# [NbConvertApp] Writing 1330 bytes to processor.py
# Calculating RF Score............
# astral incomplete 8-15 1_gt_species.out.tre 0.4117647058823529
# astral incomplete 12-14 1_gt_species.out.tre 0.2647058823529412
# astral incomplete 13-16 1_gt_species.out.tre 0.5588235294117647
# Done..............................

# %%
# !jupyter nbconvert --to script analyzer.ipynb
# !python analyzer.py
# Out:
# [NbConvertApp] Converting notebook analyzer.ipynb to script
# [NbConvertApp] Writing 1571 bytes to analyzer.py
# Missing Range:  12-14
# Total Number of Trees in Terrace:  135
# Number of Trees Better than ASTRAL :  100 	 percentage ;  74.07407407407408 %
# Number of Trees Equal to ASTRAL :  26 	 percentage ;  19.25925925925926 %
# Number of Trees Worse than ASTRAL :  9 	 percentage ;  6.666666666666667 %
# Missing Range:  13-16
# Total Number of Trees in Terrace:  819
# Number of Trees Better than ASTRAL :  128 	 percentage ;  15.628815628815628 %
# Number of Trees Equal to ASTRAL :  352 	 percentage ;  42.97924297924298 %
# Number of Trees Worse than ASTRAL :  339 	 percentage ;  41.39194139194139 %
