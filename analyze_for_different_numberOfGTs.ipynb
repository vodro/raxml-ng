# %%
import numpy as np
import pandas as pd

# %%
GT_FILE_NAME = '1_gt.tre'
TEST_NUMBER_OF_GTS = 6

# %%
# !mkdir -p in
# !cp dataset/taxa-37/gene-tree/noscale.200g.500b/1_gt.tre in/

# %%
#keep first 10 lines of the file. Delete the rest
file = open("in/"+GT_FILE_NAME, "r")
file_content = file.readlines()
file.close()
file = open("in/"+GT_FILE_NAME, "w")
file_content = file_content[:TEST_NUMBER_OF_GTS]
file.writelines(file_content)
file.close()

# %%
# !./run_for_different_range.sh
# Out:
# Running Preprocessing......................
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/gt/1_gt.tre
# --------------- Pruning started  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/gt/1_gt.tre (  8 - 15 ) ---------------
# --------------- Pruning done  0 s  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/gt/1_gt.tre (  8 - 15 ) ---------------
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/gt/1_gt.tre
# --------------- Pruning started  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/gt/1_gt.tre (  12 - 14 ) ---------------
# --------------- Pruning done  0 s  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/gt/1_gt.tre (  12 - 14 ) ---------------
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/gt/1_gt.tre
# --------------- Pruning started  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/gt/1_gt.tre (  13 - 16 ) ---------------
# --------------- Pruning done  0 s  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/gt/1_gt.tre (  13 - 16 ) ---------------
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/gt/1_gt.tre
# --------------- Pruning started  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/gt/1_gt.tre (  15 - 18 ) ---------------
# --------------- Pruning done  0 s  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre  ==>  /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/gt/1_gt.tre (  15 - 18 ) ---------------
#
#
# ------------------- preprocessor ran in  0.05004000663757324 s -------------
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 6 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/in/1_gt.tre
# All output trees will be *arbitrarily* rooted at ORN
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [ORN, ECH, LOX, PRO, SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH, DAS, CHO, SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI, GAL, MON, MAC]
# Taxon occupancy: {PTE=6, NEW=6, RAT=6, TAR=6, SPE=6, ORN=6, OTO=6, CHO=6, PRO=6, ORY=6, MYO=6, MIC=6, HOM=6, BOS=6, EQU=6, DIP=6, MUS=6, ECH=6, GOR=6, FEL=6, MON=6, TUP=6, PON=6, MAC=6, CAL=6, TUR=6, SUS=6, VIC=6, CAN=6, GAL=6, LOX=6, OCH=6, DAS=6, SOR=6, CAV=6, PAN=6, ERI=6}
# Number of gene trees: 6
# 0 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 269
# Number of Clusters after addition by distance: 269
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 269
# gradient0 in heuristiic: 269
# partitions formed in 0.065 secs
# Dynamic Programming starting after 0.065 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 396270
# Polytree building time: 0.003 seconds.
# Number of quartet trees in the gene trees: 396270
# Size of largest cluster: 37
# Greedy score: 334433
# estimationFactor: 1.1849010115628542
# Sub-optimal score: 334433
# Total Number of elements weighted: 293
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.8493754258460141
# Optimization score: 336582
# Optimal tree inferred in 0.1 secs.
# (OCH,(ORY,((SPE,(CAV,(DIP,(RAT,MUS)))),(TUP,((TAR,((MIC,OTO),(CAL,(NEW,(PON,(GOR,(PAN,HOM))))))),(((DAS,CHO),((ECH,(LOX,PRO)),(ORN,(GAL,(MON,MAC))))),((SOR,ERI),((PTE,MYO),((EQU,(FEL,CAN)),(VIC,(SUS,(BOS,TUR))))))))))));
# Final quartet score is: 336582
# Final normalized quartet score is: 0.8493754258460141
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{GAL, MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{LOX, PRO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{ECH, LOX, PRO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{DAS, CHO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SOR, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{PTE, MYO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{EQU, FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{BOS, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{BOS, TUR, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{VIC, BOS, TUR, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{VIC, BOS, TUR, SUS, EQU, FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{MIC, OTO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{GOR, PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{GOR, PAN, HOM, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{GOR, PAN, HOM, NEW, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{CAL, GOR, PAN, HOM, NEW, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{MIC, OTO, CAL, GOR, PAN, HOM, NEW, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{MIC, OTO, TAR, CAL, GOR, PAN, HOM, NEW, PON}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{DIP, RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{DIP, RAT, MUS, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, RAT, MUS, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, RAT, MUS, CAV, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, TUP, RAT, MUS, CAV, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH, SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH, DAS, CHO, SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{ECH, LOX, PRO, SPE, DIP, TUP, MIC, OTO, RAT, MUS, CAV, TAR, CAL, GOR, PAN, HOM, NEW, PON, ORY, OCH, DAS, CHO, SOR, VIC, BOS, TUR, SUS, PTE, MYO, EQU, FEL, CAN, ERI}
# (ORN,((GAL,(MON,MAC)0.97:0.8326990609660511)0.58:0.15415067982725836,((ECH,(LOX,PRO)0.97:0.8472978603872037)1:1.5404450409471486,((DAS,CHO)1:1.5404450409471486,(((SOR,ERI)0.51:0.1267517056391439,((PTE,MYO)1:1.5404450409471486,((EQU,(FEL,CAN)0.97:0.8472978603872037)0.87:0.4757343039547204,(VIC,(SUS,(BOS,TUR)0.83:0.4418327522790392)0.85:0.4418327522790392)1:1.5404450409471486)0.51:0.14526173241001242)0.8:0.39531273664414657)1:1.3397743454849975,((TAR,((MIC,OTO)1:1.506543489271468,(CAL,(NEW,(PON,(GOR,(PAN,HOM)0.85:0.4418327522790392)1:1.5404450409471486)0.58:0.15415067982725836)0.58:0.15415067982725836)0.56:0.21455980762281834)0.33:0.0)0.99:1.2219913098286144,(TUP,((SPE,(CAV,(DIP,(RAT,MUS)1:1.5404450409471486)0.46:0.15415067982725836)0.69:0.25835445735726087)0.88:0.5288441292686688,(ORY,OCH)0.97:0.8472978603872037)0.72:0.2866973357892413)0.39:0.0)0.89:0.5288441292686688)0.85:0.4306905757257972)0.65:0.21868920096482944)0.99:1.252762968495368));
# Weight calculation took 0.007120681 secs
# ASTRAL finished in 0.149 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/complete/astral/1_gt_species.out.tre
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 6 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/gt/1_gt.tre
# All output trees will be *arbitrarily* rooted at ORN
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [ORN, SPE, DIP, TUP, MIC, OTO, RAT, MUS, TAR, CAL, GOR, PAN, OCH, DAS, CHO, SOR, VIC, BOS, SUS, MYO, FEL, CAN, ERI, MON, GAL, ORY, CAV, PON, TUR, EQU, PRO, LOX, ECH, NEW, HOM, MAC, PTE]
# Taxon occupancy: {PTE=2, NEW=2, RAT=4, TAR=4, SPE=4, ORN=4, OTO=6, CHO=6, PRO=4, ORY=4, MYO=2, MIC=6, BOS=4, HOM=2, EQU=3, DIP=5, MUS=6, GOR=3, ECH=4, FEL=4, MON=3, TUP=4, PON=4, MAC=2, CAL=5, SUS=5, TUR=4, VIC=5, CAN=6, GAL=3, LOX=2, OCH=4, DAS=5, SOR=3, CAV=3, PAN=5, ERI=4}
# Number of gene trees: 6
# 6 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 277
# Number of Clusters after addition by distance: 277
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 3
# discarded polytomies:  [3, 3]
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 277
# Threshold 0.3333333333333333:
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 277
# max k is :0
# Number of Clusters after addition by greedy: 277
# gradient0 in heuristiic: 277
# partitions formed in 0.071 secs
# Dynamic Programming starting after 0.071 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 70406
# Polytree building time: 0.002 seconds.
# Number of quartet trees in the gene trees: 70406
# Size of largest cluster: 37
# Greedy score: 58786
# estimationFactor: 1.1976661109788045
# Sub-optimal score: 58856
# Total Number of elements weighted: 309
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.8464619492656876
# Optimization score: 59596
# Optimal tree inferred in 0.097 secs.
# (MIC,(OTO,(TAR,((NEW,(CAL,(PON,(HOM,(GOR,PAN))))),((SPE,(CAV,(DIP,(RAT,MUS)))),((TUP,(OCH,ORY)),(((ECH,(PRO,LOX)),((DAS,CHO),(ORN,(GAL,(MON,MAC))))),((SOR,((FEL,CAN),(ERI,EQU))),(PTE,(MYO,(VIC,(SUS,(BOS,TUR)))))))))))));
# Final quartet score is: 59596
# Final normalized quartet score is: 0.8464619492656876
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{MON, GAL, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{DAS, CHO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{PRO, LOX}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{PRO, LOX, ECH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{ERI, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{FEL, CAN, ERI, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{SOR, FEL, CAN, ERI, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{BOS, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{BOS, SUS, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{VIC, BOS, SUS, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{VIC, BOS, SUS, MYO, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{VIC, BOS, SUS, MYO, TUR, PTE}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SOR, VIC, BOS, SUS, MYO, FEL, CAN, ERI, TUR, EQU, PTE}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{OCH, ORY}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{TUP, OCH, ORY}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{DIP, RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{DIP, RAT, MUS, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, DIP, RAT, MUS, CAV}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{GOR, PAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{GOR, PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{GOR, PAN, PON, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{CAL, GOR, PAN, PON, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{CAL, GOR, PAN, PON, NEW, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{MIC, OTO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{MIC, OTO, TAR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{MIC, OTO, TAR, CAL, GOR, PAN, PON, NEW, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, MIC, OTO, RAT, MUS, TAR, CAL, GOR, PAN, CAV, PON, NEW, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, TAR, CAL, GOR, PAN, OCH, ORY, CAV, PON, NEW, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, TAR, CAL, GOR, PAN, OCH, SOR, VIC, BOS, SUS, MYO, FEL, CAN, ERI, ORY, CAV, PON, TUR, EQU, NEW, HOM, PTE}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, TAR, CAL, GOR, PAN, OCH, SOR, VIC, BOS, SUS, MYO, FEL, CAN, ERI, ORY, CAV, PON, TUR, EQU, PRO, LOX, ECH, NEW, HOM, PTE}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{SPE, DIP, TUP, MIC, OTO, RAT, MUS, TAR, CAL, GOR, PAN, OCH, DAS, CHO, SOR, VIC, BOS, SUS, MYO, FEL, CAN, ERI, ORY, CAV, PON, TUR, EQU, PRO, LOX, ECH, NEW, HOM, PTE}
# (ORN,((GAL,(MON,MAC)0.67:0.2876820724517809)0.67:0.2876820724517809,((DAS,CHO)0.99:1.3862943611198908,((ECH,(PRO,LOX)0.67:0.2876820724517809)0.98:1.2039728043259361,(((SOR,((FEL,CAN)0.98:1.2039728043259361,(ERI,EQU)0.42:0.0)0.85:0.5753641449035618)0.43:0.0,(PTE,(MYO,(VIC,(SUS,(BOS,TUR)0.67:0.2876820724517809)0.44:0.1053605156578264)0.87:0.6931471805599453)0.33:0.0)0.87:0.6931471805599453)1:1.5404450409471486,((TUP,(OCH,ORY)0.67:0.2876820724517809)0.39:0.0,((SPE,(CAV,(DIP,(RAT,MUS)0.98:1.2039728043259361)0.87:0.6931471805599453)0.67:0.2876820724517809)0.92:0.7027166315760962,((NEW,(CAL,(PON,(HOM,(GOR,PAN)0.67:0.2876820724517809)0.67:0.2876820724517809)0.95:0.9808292530117262)0.42:0.0)0.67:0.2876820724517809,(TAR,(OTO,MIC)0.98:1.2039728043259361)0.23:0.0)0.97:0.8354634027402008)0.23:0.0)0.85:0.45985125778171754)0.83:0.43318965612301924)0.4:0.0)0.95:0.9808292530117262));
# Weight calculation took 0.008039254 secs
# ASTRAL finished in 0.123 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/8-15/astral/1_gt_species.out.tre
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 6 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/gt/1_gt.tre
# All output trees will be *arbitrarily* rooted at ECH
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [ECH, LOX, PRO, SPE, TUP, OTO, CAV, TAR, CAL, PAN, HOM, PON, ORY, OCH, CHO, BOS, TUR, PTE, MYO, FEL, CAN, ERI, MON, MAC, GAL, DAS, DIP, NEW, MIC, SOR, SUS, EQU, VIC, MUS, ORN, RAT, GOR]
# Taxon occupancy: {PTE=5, NEW=4, TAR=5, RAT=2, SPE=6, ORN=3, OTO=4, CHO=4, PRO=2, ORY=4, MYO=5, MIC=3, HOM=6, BOS=3, EQU=5, DIP=2, MUS=4, ECH=4, GOR=1, FEL=3, MON=4, TUP=4, PON=4, MAC=6, CAL=5, TUR=4, SUS=4, CAN=4, VIC=1, GAL=3, LOX=3, OCH=3, DAS=3, SOR=5, CAV=5, PAN=4, ERI=6}
# Number of gene trees: 6
# 6 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 267
# Number of Clusters after addition by distance: 267
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 267
# gradient0 in heuristiic: 267
# partitions formed in 0.064 secs
# Dynamic Programming starting after 0.064 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 62491
# Polytree building time: 0.002 seconds.
# Number of quartet trees in the gene trees: 62491
# Size of largest cluster: 37
# Greedy score: 53526
# estimationFactor: 1.167488697081792
# Sub-optimal score: 53588
# Total Number of elements weighted: 293
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.8627962426589428
# Optimization score: 53917
# Optimal tree inferred in 0.09 secs.
# (GOR,((PAN,HOM),(PON,(MIC,((CAL,NEW),((OTO,TAR),(((ORY,OCH),((SPE,DIP),(CAV,(MUS,RAT)))),(TUP,(((ECH,(LOX,PRO)),((CHO,DAS),(GAL,(ORN,(MON,MAC))))),(((ERI,SOR),(CAN,(FEL,EQU))),((PTE,MYO),(VIC,(SUS,(BOS,TUR))))))))))))));
# Final quartet score is: 53917
# Final normalized quartet score is: 0.8627962426589428
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{LOX, PRO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{CHO, DAS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{MON, MAC, ORN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{MON, MAC, GAL, ORN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{CHO, MON, MAC, GAL, DAS, ORN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{ERI, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{FEL, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{FEL, CAN, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{FEL, CAN, ERI, SOR, EQU}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{PTE, MYO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{BOS, TUR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{BOS, TUR, SUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{BOS, TUR, SUS, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{BOS, TUR, PTE, MYO, SUS, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{BOS, TUR, PTE, MYO, FEL, CAN, ERI, SOR, SUS, EQU, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{SPE, DIP}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{MUS, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{CAV, MUS, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, CAV, DIP, MUS, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, CAV, ORY, OCH, DIP, MUS, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{OTO, TAR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{CAL, NEW}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{PAN, HOM}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{PAN, HOM, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{PAN, HOM, PON, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{PAN, HOM, PON, MIC, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{CAL, PAN, HOM, PON, NEW, MIC, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{OTO, TAR, CAL, PAN, HOM, PON, NEW, MIC, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, OTO, CAV, TAR, CAL, PAN, HOM, PON, ORY, OCH, DIP, NEW, MIC, MUS, RAT, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SPE, TUP, OTO, CAV, TAR, CAL, PAN, HOM, PON, ORY, OCH, DIP, NEW, MIC, MUS, RAT, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, TUP, OTO, CAV, TAR, CAL, PAN, HOM, PON, ORY, OCH, BOS, TUR, PTE, MYO, FEL, CAN, ERI, DIP, NEW, MIC, SOR, SUS, EQU, VIC, MUS, RAT, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{SPE, TUP, OTO, CAV, TAR, CAL, PAN, HOM, PON, ORY, OCH, CHO, BOS, TUR, PTE, MYO, FEL, CAN, ERI, MON, MAC, GAL, DAS, DIP, NEW, MIC, SOR, SUS, EQU, VIC, MUS, ORN, RAT, GOR}
# (ECH,((LOX,PRO)0.87:0.6931471805599453,(((CHO,DAS)0.87:0.6931471805599453,(GAL,(ORN,(MON,MAC)0.42:0.0)0.67:0.2876820724517809)0.87:0.6931471805599453)0.44:0.1053605156578264,((((ERI,SOR)0.44:0.026668247082161294,(CAN,(FEL,EQU)0.33:0.0)0.85:0.5108256237659905)0.41:0.07026919584655618,((PTE,MYO)0.98:1.2039728043259361,(VIC,(SUS,(BOS,TUR)0.67:0.2876820724517809)0.33:0.0)0.67:0.2876820724517809)0.83:0.4418327522790392)0.99:1.2039728043259357,(TUP,(((ORY,OCH)0.95:0.9808292530117262,((SPE,DIP)0.42:0.0,(CAV,(MUS,RAT)0.67:0.2876820724517809)0.67:0.2876820724517809)0.73:0.34955747616986843)0.84:0.5060294515024979,((OTO,TAR)0.67:0.2876820724517809,((CAL,NEW)0.33:0.0,(MIC,(PON,((PAN,HOM)0.67:0.2876820724517809,GOR)0.67:0.2876820724517809)0.67:0.2876820724517809)0.82:0.5108256237659905)0.97:0.8472978603872037)0.96:0.7741469787515883)0.6:0.17733401528291554)0.76:0.39304258810960735)0.72:0.2876820724517809)0.87:0.6931471805599453));
# Weight calculation took 0.007331666 secs
# ASTRAL finished in 0.115 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/12-14/astral/1_gt_species.out.tre
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 6 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/gt/1_gt.tre
# All output trees will be *arbitrarily* rooted at PRO
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [PRO, DIP, TUP, MIC, MUS, CAV, TAR, CAL, GOR, HOM, NEW, PON, ORY, OCH, CHO, SOR, VIC, TUR, SUS, PTE, MYO, CAN, GAL, MON, DAS, SPE, OTO, PAN, BOS, ERI, LOX, MAC, ORN, ECH, EQU, RAT, FEL]
# Taxon occupancy: {PTE=4, NEW=5, TAR=4, RAT=3, SPE=5, ORN=3, CHO=4, OTO=3, PRO=5, ORY=3, MYO=3, MIC=1, HOM=4, BOS=3, EQU=2, DIP=4, MUS=5, GOR=4, ECH=3, FEL=3, MON=4, TUP=3, PON=4, MAC=4, CAL=2, TUR=4, SUS=5, VIC=5, CAN=5, GAL=4, LOX=4, OCH=3, SOR=4, DAS=1, CAV=5, PAN=3, ERI=4}
# Number of gene trees: 6
# 6 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 269
# Number of Clusters after addition by distance: 269
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 3
# discarded polytomies:  []
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# Threshold 0.3333333333333333:
# max k is :0
# Number of Clusters after addition by greedy: 269
# gradient0 in heuristiic: 269
# partitions formed in 0.066 secs
# Dynamic Programming starting after 0.066 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 49392
# Polytree building time: 0.001 seconds.
# Number of quartet trees in the gene trees: 49392
# Size of largest cluster: 37
# Greedy score: 42075
# estimationFactor: 1.173903743315508
# Sub-optimal score: 42163
# Total Number of elements weighted: 268
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.8725907029478458
# Optimization score: 43099
# Optimal tree inferred in 0.09 secs.
# (MUS,(RAT,(CAV,((DIP,SPE),((TAR,(CAL,(NEW,(OTO,(PON,(GOR,(HOM,PAN))))))),((TUP,MIC),((ORY,OCH),((CHO,((ECH,(PRO,LOX)),(DAS,((MON,MAC),(GAL,ORN))))),((PTE,MYO),(ERI,((EQU,(CAN,FEL)),(SOR,(VIC,(SUS,(TUR,BOS)))))))))))))));
# Final quartet score is: 43099
# Final normalized quartet score is: 0.8725907029478458
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{GAL, ORN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{GAL, MON, MAC, ORN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{GAL, MON, DAS, MAC, ORN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{PTE, MYO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{CAN, FEL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{CAN, EQU, FEL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{TUR, BOS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{TUR, SUS, BOS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{VIC, TUR, SUS, BOS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{SOR, VIC, TUR, SUS, BOS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{SOR, VIC, TUR, SUS, CAN, BOS, EQU, FEL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{SOR, VIC, TUR, SUS, CAN, BOS, ERI, EQU, FEL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SOR, VIC, TUR, SUS, PTE, MYO, CAN, BOS, ERI, EQU, FEL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{TUP, MIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{HOM, PAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{GOR, HOM, PAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{GOR, HOM, PON, PAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{GOR, HOM, PON, OTO, PAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{GOR, HOM, NEW, PON, OTO, PAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{CAL, GOR, HOM, NEW, PON, OTO, PAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{TAR, CAL, GOR, HOM, NEW, PON, OTO, PAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{DIP, SPE}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{MUS, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{MUS, CAV, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{DIP, MUS, CAV, SPE, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{DIP, MUS, CAV, TAR, CAL, GOR, HOM, NEW, PON, SPE, OTO, PAN, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{DIP, TUP, MIC, MUS, CAV, TAR, CAL, GOR, HOM, NEW, PON, SPE, OTO, PAN, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{DIP, TUP, MIC, MUS, CAV, TAR, CAL, GOR, HOM, NEW, PON, ORY, OCH, SPE, OTO, PAN, RAT}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{DIP, TUP, MIC, MUS, CAV, TAR, CAL, GOR, HOM, NEW, PON, ORY, OCH, SOR, VIC, TUR, SUS, PTE, MYO, CAN, SPE, OTO, PAN, BOS, ERI, EQU, RAT, FEL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{DIP, TUP, MIC, MUS, CAV, TAR, CAL, GOR, HOM, NEW, PON, ORY, OCH, CHO, SOR, VIC, TUR, SUS, PTE, MYO, CAN, SPE, OTO, PAN, BOS, ERI, EQU, RAT, FEL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{DIP, TUP, MIC, MUS, CAV, TAR, CAL, GOR, HOM, NEW, PON, ORY, OCH, CHO, SOR, VIC, TUR, SUS, PTE, MYO, CAN, GAL, MON, DAS, SPE, OTO, PAN, BOS, ERI, MAC, ORN, EQU, RAT, FEL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{DIP, TUP, MIC, MUS, CAV, TAR, CAL, GOR, HOM, NEW, PON, ORY, OCH, CHO, SOR, VIC, TUR, SUS, PTE, MYO, CAN, GAL, MON, DAS, SPE, OTO, PAN, BOS, ERI, MAC, ORN, ECH, EQU, RAT, FEL}
# (PRO,(LOX,(ECH,((DAS,((MON,MAC)0.87:0.6931471805599453,(GAL,ORN)0.67:0.2876820724517809)0.67:0.2876820724517809)0.67:0.2876820724517809,(CHO,(((PTE,MYO)0.87:0.6931471805599453,(ERI,((EQU,(CAN,FEL)0.67:0.2876820724517809)0.87:0.6931471805599453,(SOR,(VIC,(SUS,(TUR,BOS)0.42:0.0)0.56:0.13353139262452274)0.95:0.9808292530117262)0.67:0.2876820724517809)0.79:0.4155154439616656)0.74:0.37469344944141086)0.93:0.6931471805599453,((ORY,OCH)0.67:0.2876820724517809,((TUP,MIC)0.67:0.2876820724517809,((TAR,(CAL,(NEW,(OTO,(PON,(GOR,(HOM,PAN)0.33:0.0)0.87:0.6931471805599453)0.87:0.6931471805599453)0.42:0.0)0.86:0.6641596436866931)0.42:0.0)0.98:1.2039728043259361,((DIP,SPE)0.33:0.0,(CAV,(RAT,MUS)0.87:0.6931471805599453)0.84:0.5108256237659905)0.97:0.8095575324043568)0.89:0.6931471805599453)0.42:0.0)0.74:0.35469278273474125)0.5:0.0725706928348355)0.65:0.2231435513142097)0.95:0.9808292530117262)0.87:0.6931471805599453));
# Weight calculation took 0.006691615 secs
# ASTRAL finished in 0.114 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/13-16/astral/1_gt_species.out.tre
#
# ================== ASTRAL =====================
#
# This is ASTRAL version 5.6.3
# Gene trees are treated as unrooted
# 6 trees read from /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/gt/1_gt.tre
# All output trees will be *arbitrarily* rooted at ORN
#
# ======== Running the main analysis
# Number of taxa: 37 (37 species)
# Taxa: [ORN, ECH, SPE, DIP, MIC, RAT, MUS, CAV, PAN, HOM, PON, ORY, DAS, TUR, SUS, EQU, FEL, CAN, ERI, GAL, MON, CHO, MYO, OCH, TUP, TAR, NEW, OTO, GOR, SOR, LOX, PRO, PTE, BOS, CAL, MAC, VIC]
# Taxon occupancy: {PTE=1, NEW=3, RAT=5, TAR=2, SPE=5, ORN=6, CHO=3, OTO=4, PRO=4, ORY=2, MYO=3, MIC=3, HOM=3, BOS=3, EQU=2, DIP=5, MUS=5, ECH=5, GOR=3, FEL=3, MON=5, PON=5, TUP=2, MAC=4, CAL=2, TUR=3, SUS=2, CAN=5, VIC=1, GAL=4, LOX=3, OCH=4, DAS=2, SOR=3, CAV=3, PAN=4, ERI=3}
# Number of gene trees: 6
# 6 trees have missing taxa
# Calculating quartet distance matrix (for completion of X)
# Species tree distances calculated ...
# Will attempt to complete bipartitions from X before adding using a distance matrix.
# Building set of clusters (X) from gene trees
# ------------------------------
# gradient0: 285
# Number of Clusters after addition by distance: 285
# calculating extra bipartitions to be added at level 1 ...
# Adding to X using resolutions of greedy consensus ...
# Limit for sigma of degrees:975
# polytomy size limit : 3
# discarded polytomies:  [3, 3]
# Threshold 0.0:
# Threshold 0.01:
# Threshold 0.02:
# Threshold 0.05:
# Threshold 0.1:
# Threshold 0.2:
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 287
# Threshold 0.3333333333333333:
# polytomy of size 3; rounds with additions with at least 5 support: 0; clusters: 287
# max k is :0
# Number of Clusters after addition by greedy: 287
# gradient0 in heuristiic: 287
# partitions formed in 0.073 secs
# Dynamic Programming starting after 0.073 secs
# Using tree-based weight calculation.
# Using polytree-based weight calculation.
# Polytree max score: 34960
# Polytree building time: 0.002 seconds.
# Number of quartet trees in the gene trees: 34960
# Size of largest cluster: 37
# Greedy score: 29188
# estimationFactor: 1.1977525010278196
# Sub-optimal score: 29624
# Total Number of elements weighted: 307
# Normalized score (portion of input quartet trees satisfied before correcting for multiple individuals): 0.8586956521739131
# Optimization score: 30020
# Optimal tree inferred in 0.099 secs.
# (MIC,(OTO,((TAR,((NEW,CAL),(PON,(HOM,(PAN,GOR))))),((TUP,((DIP,(RAT,MUS)),(SPE,(CAV,(ORY,OCH))))),(((ECH,(LOX,PRO)),((DAS,CHO),(GAL,(ORN,(MON,MAC))))),(EQU,((SOR,(ERI,(FEL,CAN))),((MYO,PTE),(SUS,(TUR,(BOS,VIC)))))))))));
# Final quartet score is: 30020
# Final normalized quartet score is: 0.8586956521739131
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{MON, MAC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{DAS, CHO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{LOX, PRO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{ECH, LOX, PRO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{FEL, CAN}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{FEL, CAN, ERI}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{FEL, CAN, ERI, SOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{MYO, PTE}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{BOS, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{TUR, BOS, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{TUR, SUS, BOS, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{TUR, SUS, MYO, PTE, BOS, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{TUR, SUS, FEL, CAN, ERI, MYO, SOR, PTE, BOS, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{TUR, SUS, EQU, FEL, CAN, ERI, MYO, SOR, PTE, BOS, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{DIP, RAT, MUS}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{CAV, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{SPE, CAV, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{SPE, DIP, RAT, MUS, CAV, ORY, OCH}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{SPE, DIP, RAT, MUS, CAV, ORY, OCH, TUP}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 1:
# 	{NEW, CAL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 0:
# 	{PAN, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{PAN, HOM, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{PAN, HOM, PON, GOR}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{PAN, HOM, PON, NEW, GOR, CAL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{PAN, HOM, PON, TAR, NEW, GOR, CAL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 2:
# 	{MIC, OTO}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 5:
# 	{MIC, PAN, HOM, PON, TAR, NEW, OTO, GOR, CAL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, MIC, RAT, MUS, CAV, PAN, HOM, PON, ORY, OCH, TUP, TAR, NEW, OTO, GOR, CAL}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 6:
# 	{SPE, DIP, MIC, RAT, MUS, CAV, PAN, HOM, PON, ORY, TUR, SUS, EQU, FEL, CAN, ERI, MYO, OCH, TUP, TAR, NEW, OTO, GOR, SOR, PTE, BOS, CAL, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{ECH, SPE, DIP, MIC, RAT, MUS, CAV, PAN, HOM, PON, ORY, TUR, SUS, EQU, FEL, CAN, ERI, MYO, OCH, TUP, TAR, NEW, OTO, GOR, SOR, LOX, PRO, PTE, BOS, CAL, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 3:
# 	{ECH, SPE, DIP, MIC, RAT, MUS, CAV, PAN, HOM, PON, ORY, DAS, TUR, SUS, EQU, FEL, CAN, ERI, CHO, MYO, OCH, TUP, TAR, NEW, OTO, GOR, SOR, LOX, PRO, PTE, BOS, CAL, VIC}
# You may want to ignore posterior probabilities and other statistics related to the following branch branch because the effective number of genes impacting it is only 4:
# 	{ECH, SPE, DIP, MIC, RAT, MUS, CAV, PAN, HOM, PON, ORY, DAS, TUR, SUS, EQU, FEL, CAN, ERI, GAL, CHO, MYO, OCH, TUP, TAR, NEW, OTO, GOR, SOR, LOX, PRO, PTE, BOS, CAL, VIC}
# (ORN,((MON,MAC)0.67:0.2876820724517809,(GAL,((DAS,CHO)0.67:0.2876820724517809,((ECH,(LOX,PRO)0.87:0.6931471805599453)0.95:0.9808292530117262,((EQU,((SOR,(ERI,(FEL,CAN)0.67:0.2876820724517809)0.33:0.0)0.87:0.6931471805599453,((MYO,PTE)0.67:0.2876820724517809,(SUS,(TUR,(BOS,VIC)0.67:0.2876820724517809)0.33:0.0)0.67:0.2876820724517809)0.87:0.6931471805599453)0.42:0.0)0.87:0.6931471805599453,((TUP,((DIP,(RAT,MUS)0.95:0.9808292530117262)0.64:0.2059314224330885,(SPE,(CAV,(ORY,OCH)0.67:0.2876820724517809)0.16:0.0)0.34:0.022472855852058514)0.87:0.6931471805599453)0.42:0.0,((TAR,((NEW,CAL)0.67:0.2876820724517809,(PON,(HOM,(PAN,GOR)0.33:0.0)0.87:0.6931471805599453)0.95:0.9808292530117262)0.85:0.6325225587435105)0.42:0.0,(OTO,MIC)0.87:0.6931471805599453)0.85:0.4700036292457356)0.94:0.6649763035932491)0.85:0.4326160971741152)0.44:0.1053605156578264)0.95:0.9808292530117262)0.23:0.0));
# Weight calculation took 0.006930242 secs
# ASTRAL finished in 0.125 secs
#  processing /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/astral/1_gt_species.tre
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/astral/1_gt_species.tre was processed and saved as /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/astral/1_gt_species.out.tre.
# /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/astral/1_gt_species.out.tre
# sed: 1: "/Users/sayemhasan/Deskt ...": bad flag in substitute command: 'n'
# Finally processed /Users/sayemhasan/Desktop/Thesis/Terraces/raxml-ng/out/incomplete/15-18/astral/1_gt_species.out.tre
# Finding Terraces for different ranges......
# [NbConvertApp] Converting notebook processor.ipynb to script
# [NbConvertApp] Writing 1330 bytes to processor.py
# [NbConvertApp] Converting notebook processor.ipynb to script
# [NbConvertApp] Writing 1330 bytes to processor.py
# [NbConvertApp] Converting notebook processor.ipynb to script
# [NbConvertApp] Writing 1330 bytes to processor.py
# [NbConvertApp] Converting notebook processor.ipynb to script
# [NbConvertApp] Writing 1330 bytes to processor.py
# Calculating RF Score............
# astral incomplete 8-15 1_gt_species.out.tre 0.35294117647058826
# astral incomplete 12-14 1_gt_species.out.tre 0.35294117647058826
# astral incomplete 13-16 1_gt_species.out.tre 0.4117647058823529
# astral incomplete 15-18 1_gt_species.out.tre 0.35294117647058826
# Done..............................

# %%
# !jupyter nbconvert --to script analyzer.ipynb
# !python analyzer.py
# Out:
# [NbConvertApp] Converting notebook analyzer.ipynb to script
# [NbConvertApp] Writing 1822 bytes to analyzer.py
# Missing Range:  8-15
# Total Number of Trees in Terrace:  3
# Number of Trees Better than ASTRAL :  1 	 percentage ;  33.33333333333333 %
# Number of Trees Equal to ASTRAL :  2 	 percentage ;  66.66666666666666 %
# Number of Trees Worse than ASTRAL :  0 	 percentage ;  0.0 %
# Astral RF Score :  0.3529411764705882 	 Terrace avg RF Score:  0.34313725490196073
# Missing Range:  12-14
# Total Number of Trees in Terrace:  15
# Number of Trees Better than ASTRAL :  1 	 percentage ;  6.666666666666667 %
# Number of Trees Equal to ASTRAL :  4 	 percentage ;  26.666666666666668 %
# Number of Trees Worse than ASTRAL :  10 	 percentage ;  66.66666666666666 %
# Astral RF Score :  0.3529411764705882 	 Terrace avg RF Score:  0.37843137254901943
# Missing Range:  13-16
# Total Number of Trees in Terrace:  3
# Number of Trees Better than ASTRAL :  0 	 percentage ;  0.0 %
# Number of Trees Equal to ASTRAL :  1 	 percentage ;  33.33333333333333 %
# Number of Trees Worse than ASTRAL :  2 	 percentage ;  66.66666666666666 %
# Astral RF Score :  0.4117647058823529 	 Terrace avg RF Score:  0.4313725490196078
# Missing Range:  15-18
# Total Number of Trees in Terrace:  45
# Number of Trees Better than ASTRAL :  25 	 percentage ;  55.55555555555556 %
# Number of Trees Equal to ASTRAL :  20 	 percentage ;  44.44444444444444 %
# Number of Trees Worse than ASTRAL :  0 	 percentage ;  0.0 %
# Astral RF Score :  0.3529411764705882 	 Terrace avg RF Score:  0.33333333333333354
